# %% [markdown]
# # **Scraping | Cyber University (BRI Institute)**

# %% [markdown]
# ## Prerequists

# %% [markdown]
# **Modul yang harus diinstall:**<br>
# `serpapi` : Untuk mengambil data dari Google Search Engine<br>
# `google-search-results` : Untuk mengambil data dari Google Search Engine<br>
# `pandas` : Untuk menyimpan hasil scraping ke csv
#
# **Cara menginstall:**
# ```bash
# pip install serpapi
# pip install google-search-results
# pip install pandas
# ```

# %%
# API_KEY= 8ad99b53192a9e2d79205b48516c9d66e4aef15e48b085d799dc0d3d8a525fb3
# Target scraping: Cyber University (BRI Institute)
# Site: https://www.google.com/maps/place/Cyber+University/@-6.3035261,106.8428613,17z/data=!4m8!3m7!1s0x2e69ed8c761affff:0x85573c41e3336634!8m2!3d-6.3035261!4d106.8454362!9m1!1b1!16s%2Fg%2F11srmdvw0y?hl=id&entry=ttu&g_ep=EgoyMDI0MTIxMS4wIKXMDSoASAFQAw%3D%3D
# Data id: 0x2e69ed8c761affff:0x85573c41e3336634

# %%
# import the necessary libraries
from serpapi import GoogleSearch
from urllib.parse import urlsplit, parse_qsl
import json
import pandas as pd
import os

# %%
# define the API key and data id
API_KEY = "8ad99b53192a9e2d79205b48516c9d66e4aef15e48b085d799dc0d3d8a525fb3"
data_id = "0x2e69ed8c761affff:0x85573c41e3336634" # place id data located inside Google Maps Place URL: located inside `data=` query parameter.

# define the output directory and file name
output_dir = "../../dataset"
output_name = "CyberU_reviews.csv"

# define the search parameters
params = {
  "api_key": API_KEY,                                 # serpapi api key
  "engine": "google_maps_reviews",                    # serpapi search engine
  "hl": "id",                                         # language of the search
  "data_id": data_id  # place id data located inside Google Maps Place URL: located inside `data=` query parameter. 
}

# search for the reviews
search = GoogleSearch(params)

# create an empty list to store the reviews
reviews = []

# loop through the pages to extract the reviews
page_num = 0
while True:
    page_num += 1
    try:
        results = search.get_dict()
    except ConnectionError as e:
        print(f"Connection error: {e}")
        continue
    if "error" not in results:
        print(f"Extracting reviews from {page_num} page.")

    if not "error" in results:
        for result in results.get("reviews", []): # return an empty list [] if no reviews from the place
            reviews.append({
                "page": page_num,
                "name": result.get("user").get("name"),
                "link": result.get("user").get("link"),
                "thumbnail": result.get("user").get("thumbnail"),
                "rating": result.get("rating"),
                "date": result.get("date"),
                "snippet": result.get("snippet"),
                "images": result.get("images"),
                "local_guide": result.get("user").get("local_guide"),
                # other data
            })
    else:
        print(results["error"])
        break

    serpapi_pagination = results.get("serpapi_pagination")
    if serpapi_pagination and serpapi_pagination.get("next") and serpapi_pagination.get("next_page_token"):
        # split URL in parts as a dict and update search "params" variable to a new page that will be passed to GoogleSearch()
        search.params_dict.update(dict(parse_qsl(urlsplit(serpapi_pagination["next"]).query)))
    else:
        break

    
print(json.dumps(reviews, indent=2, ensure_ascii=False))
df = pd.DataFrame(reviews)
# Ensure the directory exists
os.makedirs(output_dir, exist_ok=True)

# Save the dataframe to a CSV file
df.to_csv(os.path.join(output_dir, output_name), index=False)
# Out:
# Extracting reviews from 1 page.
# Extracting reviews from 2 page.
# Extracting reviews from 3 page.
# Extracting reviews from 4 page.
# Extracting reviews from 5 page.
# Extracting reviews from 6 page.
# Extracting reviews from 7 page.
# Extracting reviews from 8 page.
# Google hasn't returned any results for this query.
# [
#   {
#     "page": 1,
#     "name": "Mahasiswa Pelajar",
#     "link": "https://www.google.com/maps/contrib/112543931638230760355?hl=id",
#     "thumbnail": "https://lh3.googleusercontent.com/a-/ALV-UjVjyYXn2YYmpStUE3RTNihsw_Cq2gw4-UB6Yv24cqmM-TnXGMjP=s120-c-rp-mo-br100",
#     "rating": 5.0,
#     "date": "seminggu lalu",
#     "snippet": "Lokasi Kampusnya strategis, 1 menit keluar tol pasar minggu\nlulusan nya memiliki kompetensi dan knowledge keren, ga percaya? cek di google via meta ai juga boleh\n\n#Cyberian #NewGeneration",
#     "images": null,
#     "local_guide": null
#   },
#   {
#     "page": 1,
#     "name": "Fathia Rizky",
#     "link": "https://www.google.com/maps/contrib/103682754447822984153?hl=id",
#     "thumbnail": "https://lh3.googleusercontent.com/a-/ALV-UjXng64YeHggA_Q-bosoxIaFwOQLEhVFxdCX6k10K9Xkn7GeKbrT=s120-c-rp-mo-br100",
#     "rating": 5.0,
#     "date": "2 minggu lalu",
#     "snippet": "fasilitas nya ⭐⭐⭐⭐⭐\nac nya masyaallah dingin bgt 🥶",
#     "images": null,
#     "local_guide": true
#   },
#   {
#     "page": 1,
#     "name": "Michael Sitorus",
#     "link": "https://www.google.com/maps/contrib/114923930874000912584?hl=id",
#     "thumbnail": "https://lh3.googleusercontent.com/a-/ALV-UjVv96Whdpmygv_ycdw9Day0ThO5VAQ0l2yJNe5pLPzEkq_L6370=s120-c-rp-mo-br100",
#     "rating": 5.0,
#     "date": "setahun lalu",
#     "snippet": "Kampus yang cocok untuk era digitalisasi dan milenial. Kampusnya keren...",
#     "images": [
#       "https://lh5.googleusercontent.com/p/AF1QipPj3U3noxRZMTXSVVGGpozL1tEcgh82GffH6NPu=w150-h150-k-no-p"
#     ],
#     "local_guide": true
#   },
#   {
#     "page": 1,
#     "name": "Malinda Malinda",
#     "link": "https://www.google.com/maps/contrib/102717972471292405777?hl=id",
#     "thumbnail": "https://lh3.googleusercontent.com/a-/ALV-UjVehfP0CINOt2nw16tBBBGNp5LVoebHeIutW3GjHOOGFWvawynX=s120-c-rp-mo-br100",
#     "rating": 5.0,
#     "date": "2 minggu lalu",
#     "snippet": "dosen dosen Universitas Siber Indonesia, berpengalaman",
#     "images": null,
#     "local_guide": true
#   },
#   {
#     "page": 1,
#     "name": "Yudi Mulyawan",
#     "link": "https://www.google.com/maps/contrib/102215810879756819759?hl=id",
#     "thumbnail": "https://lh3.googleusercontent.com/a-/ALV-UjWFgjVPfZEyz-kscQeVb7D6zCOs0yqi9SKa1oUzhnIPmnC9myrl=s120-c-rp-mo-br100",
#     "rating": 5.0,
#     "date": "setahun lalu",
#     "snippet": "Kampus saya makin keren aja,\n😁, sebagai angkatan pertama yang lulus semoga makin banyak adek kelas saya 🥳\nDosen nya keren keren 🙌🏻",
#     "images": null,
#     "local_guide": null
#   },
#   {
#     "page": 1,
#     "name": "Nur Raly",
#     "link": "https://www.google.com/maps/contrib/105200782718266893741?hl=id",
#     "thumbnail": "https://lh3.googleusercontent.com/a/ACg8ocITDfi0uFGtdi5cYnxX31jatR79C3dWQUc3nAizzbvL0SEIuA=s120-c-rp-mo-br100",
#     "rating": 5.0,
#     "date": "setahun lalu",
#     "snippet": "Pengajar yg bepengalam, kampus yg nyaman, biaya kuliah terjangkau dan cocok untuk calon mahasiswa yg milenial",
#     "images": [
#       "https://lh5.googleusercontent.com/p/AF1QipNFq7NsKu4MYZANECy2L9bI5jpKzKMtlBQeEpzd=w150-h150-k-no-p"
#     ],
#     "local_guide": null
#   },
#   {
#     "page": 1,
#     "name": "Hendra Rudystira",
#     "link": "https://www.google.com/maps/contrib/101941037471723594210?hl=id",
#     "thumbnail": "https://lh3.googleusercontent.com/a-/ALV-UjXML4y4uSiqikZa-bNxM0XzCxULr2knioHmDV22iNp1uYEUriXnPw=s120-c-rp-mo-ba2-br100",
#     "rating": 5.0,
#     "date": "setahun lalu",
#     "snippet": "Berawal dari BRI Institute, menjadikan Cyber University kampus baru yg mendapat banyak kepercayaan dr orang tua utk mengkuliahkan putra/i nya disini. 👍👍",
#     "images": null,
#     "local_guide": true
#   },
#   {
#     "page": 1,
#     "name": "Palupi R",
#     "link": "https://www.google.com/maps/contrib/110272744841489112001?hl=id",
#     "thumbnail": "https://lh3.googleusercontent.com/a-/ALV-UjWXV6Vhzk6HnsilCUGXXPbbfN84FV_bOps_Wyl-oclWNHTkE-uj=s120-c-rp-mo-br100",
#     "rating": 5.0,
#     "date": "setahun lalu",
#     "snippet": "ternyata ada kampus bagus di TB Simatupang...",
#     "images": [
#       "https://lh5.googleusercontent.com/p/AF1QipMur02ae7PT2txNh0CfS5fjSpT2VXiOAVjYd_fQ=w150-h150-k-no-p"
#     ],
#     "local_guide": null
#   },
#   {
#     "page": 2,
#     "name": "Andreas Wardoyo",
#     "link": "https://www.google.com/maps/contrib/106435452213084803574?hl=id",
#     "thumbnail": "https://lh3.googleusercontent.com/a-/ALV-UjX3bpcxvXdcFH-wN8SZOYmR7ftmZjs4TX1N2qKy5tq3w0dYYvNI=s120-c-rp-mo-ba4-br100",
#     "rating": 5.0,
#     "date": "4 bulan lalu",
#     "snippet": "Baik sekali",
#     "images": null,
#     "local_guide": true
#   },
#   {
#     "page": 2,
#     "name": "Desvika Elsar",
#     "link": "https://www.google.com/maps/contrib/110060935176372954826?hl=id",
#     "thumbnail": "https://lh3.googleusercontent.com/a/ACg8ocKwoyDmnhV_rO5kWcj4fcSEnYVKUlbkl1DMHwX3N1MOte8oQQ=s120-c-rp-mo-br100",
#     "rating": 5.0,
#     "date": "setahun lalu",
#     "snippet": "Kampusnya sangat nyaman terutama di perpusnya, lokasi strategis.",
#     "images": null,
#     "local_guide": null
#   },
#   {
#     "page": 2,
#     "name": "Dwipo Setyantoro",
#     "link": "https://www.google.com/maps/contrib/117251575192724114184?hl=id",
#     "thumbnail": "https://lh3.googleusercontent.com/a-/ALV-UjWuyA3VQ6dydaJusp3BH2mFxDyzY7ngjXDokL5hOE9kIDZKgVul=s120-c-rp-mo-br100",
#     "rating": 5.0,
#     "date": "setahun lalu",
#     "snippet": "Kampus nyaman dengan kesempatan magang di industri selama 2 semester bagi para mahasiswanya",
#     "images": null,
#     "local_guide": null
#   },
#   {
#     "page": 2,
#     "name": "Online Video",
#     "link": "https://www.google.com/maps/contrib/114909514624327572510?hl=id",
#     "thumbnail": "https://lh3.googleusercontent.com/a-/ALV-UjW8dzwYokOFgI06OQ5YrfcQz-LlPefp_m5QwT0ZZekID2VnrVg8=s120-c-rp-mo-br100",
#     "rating": 5.0,
#     "date": "5 bulan lalu",
#     "snippet": "kampus yang baik dan nyaman",
#     "images": null,
#     "local_guide": null
#   },
#   {
#     "page": 2,
#     "name": "ZIL ZIL",
#     "link": "https://www.google.com/maps/contrib/101997930498858643197?hl=id",
#     "thumbnail": "https://lh3.googleusercontent.com/a-/ALV-UjVwK_tb0MArT6ti_jm4JPaM31GKQKnvd5p_QJ7Ve18nXcLYba_2=s120-c-rp-mo-br100",
#     "rating": 5.0,
#     "date": "setahun lalu",
#     "snippet": "bagus kampusnya, bersih enak buat belajar",
#     "images": null,
#     "local_guide": null
#   },
#   {
#     "page": 2,
#     "name": "wahyu Susetyo",
#     "link": "https://www.google.com/maps/contrib/115653515232583448824?hl=id",
#     "thumbnail": "https://lh3.googleusercontent.com/a/ACg8ocKR0WuqY3uMFiZNdRnuK6YhsTzkmWq0PJc2zPysW52f4r4yiw=s120-c-rp-mo-br100",
#     "rating": 5.0,
#     "date": "setahun lalu",
#     "snippet": "Kampus terkeren dengan dosen yang luar biasa, sukses selalu..",
#     "images": null,
#     "local_guide": null
#   },
#   {
#     "page": 2,
#     "name": "Sofian Wirahadi",
#     "link": "https://www.google.com/maps/contrib/113027527361967954448?hl=id",
#     "thumbnail": "https://lh3.googleusercontent.com/a-/ALV-UjUieN6nEcm03Dd0Jkvfxv-KHXgs3WV4vj0bOdHhvIZ6mCxOpwvh=s120-c-rp-mo-br100",
#     "rating": 5.0,
#     "date": "setahun lalu",
#     "snippet": "Kampus Cyber University bersih dan nyaman, adminnya juga baik dalam menyampaikan informasi tentang perkuliahan ...",
#     "images": null,
#     "local_guide": null
#   },
#   {
#     "page": 2,
#     "name": "Rifka Widyastuti",
#     "link": "https://www.google.com/maps/contrib/106870003409390150580?hl=id",
#     "thumbnail": "https://lh3.googleusercontent.com/a-/ALV-UjUTcPMIUbCCjI8hBQBC8ky5Frix8lZ4GqMHlYTQph1C-k4-T87u=s120-c-rp-mo-br100",
#     "rating": 5.0,
#     "date": "setahun lalu",
#     "snippet": "semangat bangkit membangun negeri bersama The New Generation dengan bekal ilmu IT dan Digital Enterpreneur",
#     "images": null,
#     "local_guide": true
#   },
#   {
#     "page": 2,
#     "name": "Arisena Hendrawan",
#     "link": "https://www.google.com/maps/contrib/115915145970136308403?hl=id",
#     "thumbnail": "https://lh3.googleusercontent.com/a-/ALV-UjXvnaSAtC0z1sl5ZTt2IgqFjDshHiB-RIrKSo8IS6e4g2zV1K8L=s120-c-rp-mo-br100",
#     "rating": 5.0,
#     "date": "setahun lalu",
#     "snippet": "Dosen muda yang punya pengalaman bidang IT, ekonomi, kewirausahaan dan digital entrepreneur.",
#     "images": null,
#     "local_guide": null
#   },
#   {
#     "page": 2,
#     "name": "Warjy Ortega",
#     "link": "https://www.google.com/maps/contrib/107522284914656320530?hl=id",
#     "thumbnail": "https://lh3.googleusercontent.com/a-/ALV-UjUKaO4rOv9o_sEKgKLJm1-prqKFIVBK0_EpCbB4bR2jS6aaMU8H1w=s120-c-rp-mo-ba6-br100",
#     "rating": 5.0,
#     "date": "setahun lalu",
#     "snippet": "Kampusnya keren seh, prodinya apa aja min?",
#     "images": null,
#     "local_guide": true
#   },
#   {
#     "page": 3,
#     "name": "Safrilla Bagas",
#     "link": "https://www.google.com/maps/contrib/116322050576013264586?hl=id",
#     "thumbnail": "https://lh3.googleusercontent.com/a-/ALV-UjVS1ke-AmXPbl24D3Jf0g-5v4TL9Ig4qmOZtP1HQtN3zDK6-ic=s120-c-rp-mo-br100",
#     "rating": 5.0,
#     "date": "setahun lalu",
#     "snippet": "Lokasi kampus nya sangat strategis👍👍",
#     "images": null,
#     "local_guide": null
#   },
#   {
#     "page": 3,
#     "name": "Matius Zagoto",
#     "link": "https://www.google.com/maps/contrib/115217925568875054981?hl=id",
#     "thumbnail": "https://lh3.googleusercontent.com/a-/ALV-UjVDDstUcvM8LApodSOXQuFKn-RXcUII5SLPqSL_6AC1_VGf10-y=s120-c-rp-mo-br100",
#     "rating": 5.0,
#     "date": "setahun lalu",
#     "snippet": "Lokasi yang strategis Dosen yang sudah berpengalaman",
#     "images": null,
#     "local_guide": null
#   },
#   {
#     "page": 3,
#     "name": "Gunawan Witjaksono, PhD",
#     "link": "https://www.google.com/maps/contrib/116867779814787592842?hl=id",
#     "thumbnail": "https://lh3.googleusercontent.com/a/ACg8ocJma3Tj_nTXhhQq8dtGmseqK5keIM571keM4EDzGmzRsvT4Fw=s120-c-rp-mo-br100",
#     "rating": 5.0,
#     "date": "setahun lalu",
#     "snippet": "Kampusnya keren dan mudah aksesnya",
#     "images": null,
#     "local_guide": null
#   },
#   {
#     "page": 3,
#     "name": "rian septian",
#     "link": "https://www.google.com/maps/contrib/100633497027760463284?hl=id",
#     "thumbnail": "https://lh3.googleusercontent.com/a-/ALV-UjXs9nk83m09-Y_dEssX_41Mh35CzJZoGvOYDd1PaK5wPUeSFOaa=s120-c-rp-mo-br100",
#     "rating": 5.0,
#     "date": "setahun lalu",
#     "snippet": "Sangat bagus terutama dosennya baik baik",
#     "images": null,
#     "local_guide": true
#   },
#   {
#     "page": 3,
#     "name": "Agung Fazriansyah",
#     "link": "https://www.google.com/maps/contrib/101704871603504953229?hl=id",
#     "thumbnail": "https://lh3.googleusercontent.com/a/ACg8ocJ57v8JjbdHS9kX33cJguINI_xSkZqEHgYCRWRqa0tNLKGpJg=s120-c-rp-mo-br100",
#     "rating": 5.0,
#     "date": "setahun lalu",
#     "snippet": "Kampus dengan fasilitas yang nyaman dan keren",
#     "images": null,
#     "local_guide": null
#   },
#   {
#     "page": 3,
#     "name": "Rizki Hesananda",
#     "link": "https://www.google.com/maps/contrib/111333411758941685571?hl=id",
#     "thumbnail": "https://lh3.googleusercontent.com/a-/ALV-UjWRijoY_hGSrlXwqDLFRi4CCkgWST0eUGhttCrlcfko-RhJhEA7=s120-c-rp-mo-ba6-br100",
#     "rating": 5.0,
#     "date": "setahun lalu",
#     "snippet": "ruangan kampusnya keren abis",
#     "images": null,
#     "local_guide": true
#   },
#   {
#     "page": 3,
#     "name": "hasan basri",
#     "link": "https://www.google.com/maps/contrib/106157665581372498841?hl=id",
#     "thumbnail": "https://lh3.googleusercontent.com/a-/ALV-UjWsCbI9004aahioxpCw9Ul1p5jfw_2k7scFxUCEMmoCL7FmOYI1MA=s120-c-rp-mo-br100",
#     "rating": 5.0,
#     "date": "setahun lalu",
#     "snippet": "Suka perpus nya ...",
#     "images": null,
#     "local_guide": null
#   },
#   {
#     "page": 3,
#     "name": "Yavin Ginting",
#     "link": "https://www.google.com/maps/contrib/112463705448460420298?hl=id",
#     "thumbnail": "https://lh3.googleusercontent.com/a-/ALV-UjW8pkCojuiLpeSLFAoBE1v6Ah3Ihjtd4UENfj-qWIAfkSY88rzF=s120-c-rp-mo-br100",
#     "rating": 5.0,
#     "date": "setahun lalu",
#     "snippet": "ruangan bagus",
#     "images": null,
#     "local_guide": null
#   },
#   {
#     "page": 3,
#     "name": "Kastin Tinara",
#     "link": "https://www.google.com/maps/contrib/115188137155934272569?hl=id",
#     "thumbnail": "https://lh3.googleusercontent.com/a-/ALV-UjU9qGvTtKkiYMQ-PexX91P25hqN-r6Zc94MijEXkbfj3vcgWNbu=s120-c-rp-mo-br100",
#     "rating": 5.0,
#     "date": "setahun lalu",
#     "snippet": "Kampusnya kerenn 👍👍",
#     "images": null,
#     "local_guide": true
#   },
#   {
#     "page": 3,
#     "name": "Putri Artanti",
#     "link": "https://www.google.com/maps/contrib/101136190056865488279?hl=id",
#     "thumbnail": "https://lh3.googleusercontent.com/a-/ALV-UjWPJQiPDTa0749RrYOuzn8mr_Hxqqt3caiZCuLDhAzvaTv6ZIeg=s120-c-rp-mo-br100",
#     "rating": 5.0,
#     "date": "setahun lalu",
#     "snippet": "kampus dengan akses sangat mudah",
#     "images": null,
#     "local_guide": null
#   },
#   {
#     "page": 4,
#     "name": "Yulita ayu Wardani",
#     "link": "https://www.google.com/maps/contrib/112231540094938800204?hl=id",
#     "thumbnail": "https://lh3.googleusercontent.com/a-/ALV-UjW7eMkLa4mtsXRzbI24IUysIww4Dycvud9dibP8ibO36MVdchy1=s120-c-rp-mo-br100",
#     "rating": 5.0,
#     "date": "setahun lalu",
#     "snippet": "Dosen dan staffnya keren",
#     "images": null,
#     "local_guide": null
#   },
#   {
#     "page": 4,
#     "name": "Abung Widodo",
#     "link": "https://www.google.com/maps/contrib/106560198597179875230?hl=id",
#     "thumbnail": "https://lh3.googleusercontent.com/a/ACg8ocJwTfExUewGoR90lN666BbUGA8SvQsZxqYAJ3ZC66AvkNnf=s120-c-rp-mo-br100",
#     "rating": 5.0,
#     "date": "setahun lalu",
#     "snippet": "Dosennya sangat ramah",
#     "images": null,
#     "local_guide": null
#   },
#   {
#     "page": 4,
#     "name": "Marghiasto Fajar S S",
#     "link": "https://www.google.com/maps/contrib/112135707328777691819?hl=id",
#     "thumbnail": "https://lh3.googleusercontent.com/a-/ALV-UjVnE4J3xyiTiOhm4-ElLF4r6FwMSw0Umm9p_nMk2UASEzBuouPJAA=s120-c-rp-mo-br100",
#     "rating": 5.0,
#     "date": "setahun lalu",
#     "snippet": "strategis & nyaman",
#     "images": null,
#     "local_guide": null
#   },
#   {
#     "page": 4,
#     "name": "alwie risnandar",
#     "link": "https://www.google.com/maps/contrib/109258984151134302767?hl=id",
#     "thumbnail": "https://lh3.googleusercontent.com/a-/ALV-UjUp16VdWSQfcdgV1Vm38Nvn8M73X-2tf0TpvBHM6SorzeHp37g=s120-c-rp-mo-br100",
#     "rating": 5.0,
#     "date": "setahun lalu",
#     "snippet": "Lokasinya strategis..",
#     "images": null,
#     "local_guide": null
#   },
#   {
#     "page": 4,
#     "name": "Utomoadji Wisnubroto (Tom's Alpha XP)",
#     "link": "https://www.google.com/maps/contrib/117386783683131819251?hl=id",
#     "thumbnail": "https://lh3.googleusercontent.com/a-/ALV-UjWWY-wi4OZVh4IPqD-fKtH484v_m4_ZUp2d0weKS65EIb2lykbC=s120-c-rp-mo-ba2-br100",
#     "rating": 5.0,
#     "date": "setahun lalu",
#     "snippet": "Kampus yang Mantab",
#     "images": null,
#     "local_guide": true
#   },
#   {
#     "page": 4,
#     "name": "Ishak Kholil",
#     "link": "https://www.google.com/maps/contrib/112102326063961845093?hl=id",
#     "thumbnail": "https://lh3.googleusercontent.com/a-/ALV-UjU1BBTSNX6IYyrqec3AADGiIk-SlBwpi2Rw3dY7D0oVeih721B7=s120-c-rp-mo-br100",
#     "rating": 5.0,
#     "date": "setahun lalu",
#     "snippet": "Strategis Lokasinya",
#     "images": null,
#     "local_guide": true
#   },
#   {
#     "page": 4,
#     "name": "Dicky Hariyanto",
#     "link": "https://www.google.com/maps/contrib/111908938437435635269?hl=id",
#     "thumbnail": "https://lh3.googleusercontent.com/a-/ALV-UjVnMfyMoHStmqod_cpoFVt0VjEWkX96J1vtO7RafI9rGyUcsMys=s120-c-rp-mo-ba2-br100",
#     "rating": 5.0,
#     "date": "setahun lalu",
#     "snippet": "Kampus keren di Jakarta Selatan",
#     "images": null,
#     "local_guide": true
#   },
#   {
#     "page": 4,
#     "name": "N Putra SK",
#     "link": "https://www.google.com/maps/contrib/103744568030435622792?hl=id",
#     "thumbnail": "https://lh3.googleusercontent.com/a-/ALV-UjU8dPGg8GUv4CMw2nroZrJfaQH27fc9QVI8CwHXwjdNqhFQ7GRf=s120-c-rp-mo-br100",
#     "rating": 5.0,
#     "date": "setahun lalu",
#     "snippet": "Very enjoyable",
#     "images": [
#       "https://lh5.googleusercontent.com/p/AF1QipMucA4ThOV0YGfLDIBIiYT4w_UJoRiCpjYbWFgq=w150-h150-k-no-p"
#     ],
#     "local_guide": true
#   },
#   {
#     "page": 4,
#     "name": "A Trihandoyo",
#     "link": "https://www.google.com/maps/contrib/108074396190195459974?hl=id",
#     "thumbnail": "https://lh3.googleusercontent.com/a-/ALV-UjVvILcevwr8A_jgGcbJD-FnG_0_R4SlhT94GrHMYCL4ha4E-s0N=s120-c-rp-mo-br100",
#     "rating": 5.0,
#     "date": "setahun lalu",
#     "snippet": "Great campus to prepare young leaders in fintech",
#     "images": null,
#     "local_guide": null
#   },
#   {
#     "page": 4,
#     "name": "Anang Martoyo",
#     "link": "https://www.google.com/maps/contrib/101180309999246460967?hl=id",
#     "thumbnail": "https://lh3.googleusercontent.com/a-/ALV-UjUF_zTAfZ_MUyZocss_PpM0NoMN17lbrQUFlnvCTRP1b3meAh2J=s120-c-rp-mo-br100",
#     "rating": 5.0,
#     "date": "setahun lalu",
#     "snippet": "We wish Cyber University will be smart campoes",
#     "images": null,
#     "local_guide": null
#   },
#   {
#     "page": 5,
#     "name": "Fitria",
#     "link": "https://www.google.com/maps/contrib/117814313341065079507?hl=id",
#     "thumbnail": "https://lh3.googleusercontent.com/a-/ALV-UjXQmAlX8GztO0HRBWd58UpPzrLjyoT_g-f1_g84DD4_77-OLXtE=s120-c-rp-mo-br100",
#     "rating": 5.0,
#     "date": "setahun lalu",
#     "snippet": "the new generation IT campus",
#     "images": null,
#     "local_guide": null
#   },
#   {
#     "page": 5,
#     "name": "Ninuk Wiliani",
#     "link": "https://www.google.com/maps/contrib/109949626906104010956?hl=id",
#     "thumbnail": "https://lh3.googleusercontent.com/a-/ALV-UjUqSSA8dNOlZp5rkhVlNUL9nQjXgkkjI5go4294WhGfKqoAWjVm=s120-c-rp-mo-ba2-br100",
#     "rating": 5.0,
#     "date": "setahun lalu",
#     "snippet": "nice",
#     "images": null,
#     "local_guide": true
#   },
#   {
#     "page": 5,
#     "name": "Grimeildine Risti Farrah",
#     "link": "https://www.google.com/maps/contrib/114236675222991243398?hl=id",
#     "thumbnail": "https://lh3.googleusercontent.com/a-/ALV-UjWtAqTxQJl_OGUDIs_ujSFoaJ6uSnhByXJ3R2dyrzCnY4n1ovoxxw=s120-c-rp-mo-br100",
#     "rating": 5.0,
#     "date": "setahun lalu",
#     "snippet": null,
#     "images": null,
#     "local_guide": true
#   },
#   {
#     "page": 5,
#     "name": "ahwan eko",
#     "link": "https://www.google.com/maps/contrib/104213099191979614789?hl=id",
#     "thumbnail": "https://lh3.googleusercontent.com/a/ACg8ocIMQsXYOiVEqp0Q_z4b2aUemQjB_hMWz3P5kBGVoe7xm7uVnw=s120-c-rp-mo-br100",
#     "rating": 5.0,
#     "date": "setahun lalu",
#     "snippet": null,
#     "images": null,
#     "local_guide": null
#   },
#   {
#     "page": 5,
#     "name": "rian rafli",
#     "link": "https://www.google.com/maps/contrib/107577203143375233464?hl=id",
#     "thumbnail": "https://lh3.googleusercontent.com/a-/ALV-UjWqGNl7Av8sofcfvafJTlxL2cmAyTmXUMaCOdAWxU31_VyN3KfR=s120-c-rp-mo-br100",
#     "rating": 5.0,
#     "date": "11 bulan lalu",
#     "snippet": null,
#     "images": null,
#     "local_guide": null
#   },
#   {
#     "page": 5,
#     "name": "Ahmad Junaedi",
#     "link": "https://www.google.com/maps/contrib/100862338247706956756?hl=id",
#     "thumbnail": "https://lh3.googleusercontent.com/a-/ALV-UjUittIWqgsMabm6KXTpTtsZB2S6AokbdFJBAb3Hi09p5U3X4iwXUw=s120-c-rp-mo-br100",
#     "rating": 5.0,
#     "date": "setahun lalu",
#     "snippet": null,
#     "images": null,
#     "local_guide": null
#   },
#   {
#     "page": 5,
#     "name": "Juan Putra",
#     "link": "https://www.google.com/maps/contrib/116529969310022314305?hl=id",
#     "thumbnail": "https://lh3.googleusercontent.com/a-/ALV-UjWE4xoEleS6HvuNNbuLxjaDseYP1XXBijj0xAX5VPLAmpgSuKk=s120-c-rp-mo-br100",
#     "rating": 5.0,
#     "date": "setahun lalu",
#     "snippet": null,
#     "images": null,
#     "local_guide": true
#   },
#   {
#     "page": 5,
#     "name": "Rizky Fadhillah",
#     "link": "https://www.google.com/maps/contrib/112442087114419552317?hl=id",
#     "thumbnail": "https://lh3.googleusercontent.com/a/ACg8ocIdWXhCYjSNpSFj2EbkwfOfx1xNGlsMWJf9Ceoz__Ej91K2TA=s120-c-rp-mo-br100",
#     "rating": 5.0,
#     "date": "setahun lalu",
#     "snippet": null,
#     "images": null,
#     "local_guide": null
#   },
#   {
#     "page": 5,
#     "name": "Dwi Praja Agustian",
#     "link": "https://www.google.com/maps/contrib/113567873176110824029?hl=id",
#     "thumbnail": "https://lh3.googleusercontent.com/a-/ALV-UjVOffavSJ0emxspQcYKEXFllSQS7LRI6BmGFNMYxw7r8O3DjwwI=s120-c-rp-mo-br100",
#     "rating": 5.0,
#     "date": "setahun lalu",
#     "snippet": null,
#     "images": null,
#     "local_guide": null
#   },
#   {
#     "page": 5,
#     "name": "Sade Ayu",
#     "link": "https://www.google.com/maps/contrib/109915779348005047049?hl=id",
#     "thumbnail": "https://lh3.googleusercontent.com/a-/ALV-UjXdv45mZCoLt8RCyRQClWIlNndnKsTXP0b7MlAEXB114CHX3pJf=s120-c-rp-mo-br100",
#     "rating": 5.0,
#     "date": "setahun lalu",
#     "snippet": null,
#     "images": null,
#     "local_guide": null
#   },
#   {
#     "page": 6,
#     "name": "Maurist Irsandy",
#     "link": "https://www.google.com/maps/contrib/110966144539713352205?hl=id",
#     "thumbnail": "https://lh3.googleusercontent.com/a-/ALV-UjXgRK99cRyOEXs3llWQlA6L1i19ee55nH7MtTNTrlOukCb1mWOQlQ=s120-c-rp-mo-br100",
#     "rating": 5.0,
#     "date": "setahun lalu",
#     "snippet": null,
#     "images": null,
#     "local_guide": null
#   },
#   {
#     "page": 6,
#     "name": "Luffi",
#     "link": "https://www.google.com/maps/contrib/118282093761067585160?hl=id",
#     "thumbnail": "https://lh3.googleusercontent.com/a/ACg8ocIvMzJMZ-gd0h55C70eaH1jhma0r11whlw2tUuyZjf_0ODknQ=s120-c-rp-mo-br100",
#     "rating": 5.0,
#     "date": "setahun lalu",
#     "snippet": null,
#     "images": null,
#     "local_guide": null
#   },
#   {
#     "page": 6,
#     "name": "Arthur Richard Worotikan",
#     "link": "https://www.google.com/maps/contrib/115916815928877612125?hl=id",
#     "thumbnail": "https://lh3.googleusercontent.com/a-/ALV-UjX2_DhhMRcFYnBfDKYMjYCXWDGcvNvwSHVNa5Ll61LJZ-8Uz_0=s120-c-rp-mo-br100",
#     "rating": 5.0,
#     "date": "8 bulan lalu",
#     "snippet": null,
#     "images": null,
#     "local_guide": null
#   },
#   {
#     "page": 6,
#     "name": "Calvin Siahaan",
#     "link": "https://www.google.com/maps/contrib/117056927132140883246?hl=id",
#     "thumbnail": "https://lh3.googleusercontent.com/a/ACg8ocKWuwudExjc7wm5ig4qeyUE1uskRSdbATuyQiG7uOwCJiz0tv19=s120-c-rp-mo-br100",
#     "rating": 5.0,
#     "date": "setahun lalu",
#     "snippet": null,
#     "images": null,
#     "local_guide": null
#   },
#   {
#     "page": 6,
#     "name": "Wirzonmuhammad Wirzon",
#     "link": "https://www.google.com/maps/contrib/107828358145296867966?hl=id",
#     "thumbnail": "https://lh3.googleusercontent.com/a-/ALV-UjUkArUW7qOBDFh6GvbetUjGAXl1Sh2rI0xiqT-pawxKbiF9Zr2vtA=s120-c-rp-mo-ba4-br100",
#     "rating": 4.0,
#     "date": "3 bulan lalu",
#     "snippet": null,
#     "images": null,
#     "local_guide": true
#   },
#   {
#     "page": 6,
#     "name": "Vivi Afifah",
#     "link": "https://www.google.com/maps/contrib/117779569534009720464?hl=id",
#     "thumbnail": "https://lh3.googleusercontent.com/a-/ALV-UjVMZWgH-LwFm3KKBaPr2clj_xjBOcxlGIo3pjmqsXQJlBrkm4Rf=s120-c-rp-mo-br100",
#     "rating": 5.0,
#     "date": "setahun lalu",
#     "snippet": null,
#     "images": null,
#     "local_guide": null
#   },
#   {
#     "page": 6,
#     "name": "Anissa Novinka",
#     "link": "https://www.google.com/maps/contrib/111915863765038414204?hl=id",
#     "thumbnail": "https://lh3.googleusercontent.com/a-/ALV-UjUoih1Bch-JfWbIe9qcEReeyK8EkV4h08ZbtDe2MJUUr9uhLRJtbQ=s120-c-rp-mo-br100",
#     "rating": 5.0,
#     "date": "setahun lalu",
#     "snippet": null,
#     "images": null,
#     "local_guide": true
#   },
#   {
#     "page": 6,
#     "name": "Reza Malinda",
#     "link": "https://www.google.com/maps/contrib/113804299315268036533?hl=id",
#     "thumbnail": "https://lh3.googleusercontent.com/a/ACg8ocIjtusgQAP526R5AqBzyMsRbF7TnfL7B7IJoqmpSI3qE3skow=s120-c-rp-mo-br100",
#     "rating": 5.0,
#     "date": "setahun lalu",
#     "snippet": null,
#     "images": null,
#     "local_guide": null
#   },
#   {
#     "page": 6,
#     "name": "Arsya Anindita",
#     "link": "https://www.google.com/maps/contrib/105416682639004554122?hl=id",
#     "thumbnail": "https://lh3.googleusercontent.com/a/ACg8ocL_vSzetIk4UWahhNtiR1YHAKKsRS__2upi99ZR8_HlOIi5_tAM=s120-c-rp-mo-br100",
#     "rating": 5.0,
#     "date": "setahun lalu",
#     "snippet": null,
#     "images": null,
#     "local_guide": null
#   },
#   {
#     "page": 6,
#     "name": "Doni Rahmad",
#     "link": "https://www.google.com/maps/contrib/113313158493229150147?hl=id",
#     "thumbnail": "https://lh3.googleusercontent.com/a/ACg8ocLDIiwckrzQ23ore-VPhxUJvgm1jZcwZW7KdMUCzbVg-4C7LQ=s120-c-rp-mo-br100",
#     "rating": 5.0,
#     "date": "setahun lalu",
#     "snippet": null,
#     "images": null,
#     "local_guide": null
#   },
#   {
#     "page": 7,
#     "name": "Naufal Maulana S",
#     "link": "https://www.google.com/maps/contrib/116228528699629826880?hl=id",
#     "thumbnail": "https://lh3.googleusercontent.com/a-/ALV-UjVEYAfXgB-N-bK_h_ccel4XB1YvaSC6Pkml3ATHR98JFRnOEihZ=s120-c-rp-mo-br100",
#     "rating": 5.0,
#     "date": "setahun lalu",
#     "snippet": null,
#     "images": null,
#     "local_guide": true
#   },
#   {
#     "page": 7,
#     "name": "Angelia Indrianti",
#     "link": "https://www.google.com/maps/contrib/107264124277706641755?hl=id",
#     "thumbnail": "https://lh3.googleusercontent.com/a/ACg8ocIIJtywdRxDw5hAwH9x8n5pN1qcrbfM4Lx76vnz_VskomuoQg=s120-c-rp-mo-br100",
#     "rating": 5.0,
#     "date": "setahun lalu",
#     "snippet": null,
#     "images": null,
#     "local_guide": null
#   },
#   {
#     "page": 7,
#     "name": "Agung Segara",
#     "link": "https://www.google.com/maps/contrib/117169883691278861567?hl=id",
#     "thumbnail": "https://lh3.googleusercontent.com/a-/ALV-UjUdH3cxRCq6wSEFaH8x-F5ChDoqz8rF-QICb7n_SeRP_LHnqkM=s120-c-rp-mo-br100",
#     "rating": 5.0,
#     "date": "setahun lalu",
#     "snippet": null,
#     "images": null,
#     "local_guide": true
#   },
#   {
#     "page": 7,
#     "name": "Yandi Wijaya",
#     "link": "https://www.google.com/maps/contrib/118224551820698267207?hl=id",
#     "thumbnail": "https://lh3.googleusercontent.com/a-/ALV-UjUeDoSEtk7w8obS3xLMZ0RDbTxZWm2wtVwm426e1UjKtlGoqTBI=s120-c-rp-mo-br100",
#     "rating": 5.0,
#     "date": "setahun lalu",
#     "snippet": null,
#     "images": null,
#     "local_guide": null
#   },
#   {
#     "page": 7,
#     "name": "Mutiara Nabillah",
#     "link": "https://www.google.com/maps/contrib/116385857656437780241?hl=id",
#     "thumbnail": "https://lh3.googleusercontent.com/a-/ALV-UjXlKOU1mXweK5evxbe-7_Wq7xdIxNx9th2xGPplRIPJ06H9alYn=s120-c-rp-mo-br100",
#     "rating": 5.0,
#     "date": "5 bulan lalu",
#     "snippet": null,
#     "images": null,
#     "local_guide": true
#   },
#   {
#     "page": 7,
#     "name": "Gilbert grandklay Marthin mongdong",
#     "link": "https://www.google.com/maps/contrib/115564076221135117656?hl=id",
#     "thumbnail": "https://lh3.googleusercontent.com/a-/ALV-UjUhnz3pbf3GYqz_8eHqstAuZhQlGfYmwVn1MmoaTtF99Pr50uow=s120-c-rp-mo-br100",
#     "rating": 5.0,
#     "date": "4 bulan lalu",
#     "snippet": null,
#     "images": null,
#     "local_guide": null
#   },
#   {
#     "page": 7,
#     "name": "HENRI NANI",
#     "link": "https://www.google.com/maps/contrib/109280658655314204211?hl=id",
#     "thumbnail": "https://lh3.googleusercontent.com/a/ACg8ocIcY9DUj3cY4ToR0u4dfEaCbRtHDnZEPBFuDOeVHOc0Jd8ZFuSq=s120-c-rp-mo-ba2-br100",
#     "rating": 5.0,
#     "date": "sebulan lalu",
#     "snippet": null,
#     "images": null,
#     "local_guide": true
#   },
#   {
#     "page": 7,
#     "name": "rika astuti hasibuan",
#     "link": "https://www.google.com/maps/contrib/105206972007633871511?hl=id",
#     "thumbnail": "https://lh3.googleusercontent.com/a-/ALV-UjULZT4G6Htvu0Fx-UiUtJ5XvMX3Uy_RrescleQnBstFgLQCeSqr=s120-c-rp-mo-br100",
#     "rating": 5.0,
#     "date": "setahun lalu",
#     "snippet": null,
#     "images": null,
#     "local_guide": null
#   },
#   {
#     "page": 7,
#     "name": "Aji Sukma",
#     "link": "https://www.google.com/maps/contrib/100676004215721655343?hl=id",
#     "thumbnail": "https://lh3.googleusercontent.com/a-/ALV-UjXuIm39DvlmdfxhDsqKvPlNNGWce2Acgr2JSi-mS-KBO7f99hbn=s120-c-rp-mo-br100",
#     "rating": 5.0,
#     "date": "setahun lalu",
#     "snippet": null,
#     "images": null,
#     "local_guide": true
#   },
#   {
#     "page": 7,
#     "name": "Rei syah",
#     "link": "https://www.google.com/maps/contrib/107290207756110659632?hl=id",
#     "thumbnail": "https://lh3.googleusercontent.com/a/ACg8ocI1YSXSQVn9LaPCIWq5aADZOnuQP_wpI6nJFrH4wQC5ZNFXrQ=s120-c-rp-mo-br100",
#     "rating": 5.0,
#     "date": "5 bulan lalu",
#     "snippet": null,
#     "images": null,
#     "local_guide": true
#   },
#   {
#     "page": 8,
#     "name": "Salwa Hafizah",
#     "link": "https://www.google.com/maps/contrib/101332035886758182825?hl=id",
#     "thumbnail": "https://lh3.googleusercontent.com/a-/ALV-UjWy5G6WaORCp_1PRSefmw7qYvyxHX0EoAko44p7iepbVd8i3pfV=s120-c-rp-mo-br100",
#     "rating": 5.0,
#     "date": "setahun lalu",
#     "snippet": null,
#     "images": null,
#     "local_guide": null
#   },
#   {
#     "page": 8,
#     "name": "amelia n",
#     "link": "https://www.google.com/maps/contrib/114437044530126019817?hl=id",
#     "thumbnail": "https://lh3.googleusercontent.com/a-/ALV-UjV-FXgX_rN99vOIDKabpnq2pXcC-0o-H8B7jipFKvHR_Lq35xY-8A=s120-c-rp-mo-br100",
#     "rating": 5.0,
#     "date": "setahun lalu",
#     "snippet": null,
#     "images": null,
#     "local_guide": true
#   },
#   {
#     "page": 8,
#     "name": "sena Dwi novaa",
#     "link": "https://www.google.com/maps/contrib/117744560309025721548?hl=id",
#     "thumbnail": "https://lh3.googleusercontent.com/a/ACg8ocLGpNQ7Sub5zjOBSzI5m5MM8fi6pQ9zuPYd1lH-PiJ_J8Tn9w=s120-c-rp-mo-br100",
#     "rating": 5.0,
#     "date": "setahun lalu",
#     "snippet": null,
#     "images": null,
#     "local_guide": null
#   },
#   {
#     "page": 8,
#     "name": "Destya Herninda",
#     "link": "https://www.google.com/maps/contrib/100724488039696582798?hl=id",
#     "thumbnail": "https://lh3.googleusercontent.com/a/ACg8ocJg-n0qNBrcToXCFuMFRFjupf63eepBbbRr2PWBAhVgQdQEBw=s120-c-rp-mo-br100",
#     "rating": 5.0,
#     "date": "setahun lalu",
#     "snippet": null,
#     "images": null,
#     "local_guide": null
#   },
#   {
#     "page": 8,
#     "name": "Helmy Afrizah",
#     "link": "https://www.google.com/maps/contrib/104120411285638095627?hl=id",
#     "thumbnail": "https://lh3.googleusercontent.com/a/ACg8ocK1lifzi4noKpNwg4XqJ4bJUrpShAmJQN8DC9I1SKdE4SIGFQ=s120-c-rp-mo-br100",
#     "rating": 5.0,
#     "date": "3 bulan lalu",
#     "snippet": null,
#     "images": null,
#     "local_guide": null
#   },
#   {
#     "page": 8,
#     "name": "k. widianto",
#     "link": "https://www.google.com/maps/contrib/104829075702785773443?hl=id",
#     "thumbnail": "https://lh3.googleusercontent.com/a-/ALV-UjVr0qf4l7OVKMLYr7W_L-Zbb8LLgQcKSE3qWLl-LGHuXA6KM2B0=s120-c-rp-mo-ba3-br100",
#     "rating": 5.0,
#     "date": "setahun lalu",
#     "snippet": null,
#     "images": null,
#     "local_guide": true
#   },
#   {
#     "page": 8,
#     "name": "Rusli Yanto",
#     "link": "https://www.google.com/maps/contrib/111367947195823633317?hl=id",
#     "thumbnail": "https://lh3.googleusercontent.com/a/ACg8ocIBMUm-e2JNyn9_uPeCxHLK54f2PxdcO89vrdRhPa1ovkIbyA=s120-c-rp-mo-br100",
#     "rating": 4.0,
#     "date": "setahun lalu",
#     "snippet": null,
#     "images": null,
#     "local_guide": null
#   },
#   {
#     "page": 8,
#     "name": "Raihan Rabbani",
#     "link": "https://www.google.com/maps/contrib/105525498960691515579?hl=id",
#     "thumbnail": "https://lh3.googleusercontent.com/a-/ALV-UjVViWOKLw5_htccaa4xGGI64k6K1eNMetrhj0pqK_UhwhYH7wxv=s120-c-rp-mo-br100",
#     "rating": 5.0,
#     "date": "setahun lalu",
#     "snippet": null,
#     "images": null,
#     "local_guide": null
#   },
#   {
#     "page": 8,
#     "name": "Ayi Wahid",
#     "link": "https://www.google.com/maps/contrib/110434801021657330149?hl=id",
#     "thumbnail": "https://lh3.googleusercontent.com/a-/ALV-UjVrar8gIBKvhwZcOVeiChKIJvGN_neoWyzkl4Wo9CgmWIka9oc=s120-c-rp-mo-br100",
#     "rating": 5.0,
#     "date": "setahun lalu",
#     "snippet": null,
#     "images": null,
#     "local_guide": null
#   },
#   {
#     "page": 8,
#     "name": "Nova Oktaviawan",
#     "link": "https://www.google.com/maps/contrib/115655762740365254770?hl=id",
#     "thumbnail": "https://lh3.googleusercontent.com/a/ACg8ocJCP8Gfm3bnhHwF5e3yt7LwXkANVtJOS6pYfYIvqhoj8_PWtg=s120-c-rp-mo-br100",
#     "rating": 5.0,
#     "date": "setahun lalu",
#     "snippet": null,
#     "images": null,
#     "local_guide": null
#   }
# ]
