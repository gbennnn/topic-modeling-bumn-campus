# %% [markdown]
# # **Preprocessing | Universitas Internasional Semen Indonesia (UISI)**

# %% [markdown]
# # Text Preprocessing (Clean Data)

# %%
import pandas as pd
import string
import re
df = pd.read_csv('../../dataset/UISI_reviews.csv')

output_path = '../../dataset/cleaned-data/UISI_Reviews_cleaned.csv'

df.head()
# Out:
#    page                   name  \
# 0     1  Firdaus Agil Prasetyo
# 1     1              Miftah NG
# 2     1       Hafiz Nafi'uddin
# 3     1        Chandra Bintang
# 4     1             Wandy Bear
#
#                                                 link  \
# 0  https://www.google.com/maps/contrib/1114238106...
# 1  https://www.google.com/maps/contrib/1127338953...
# 2  https://www.google.com/maps/contrib/1069934634...
# 3  https://www.google.com/maps/contrib/1180606762...
# 4  https://www.google.com/maps/contrib/1006073327...
#
#                                            thumbnail  rating          date  \
# 0  https://lh3.googleusercontent.com/a-/ALV-UjWYy...     5.0  2 tahun lalu
# 1  https://lh3.googleusercontent.com/a-/ALV-UjXiM...     5.0  5 tahun lalu
# 2  https://lh3.googleusercontent.com/a-/ALV-UjWTC...     3.0  setahun lalu
# 3  https://lh3.googleusercontent.com/a/ACg8ocKeJe...     1.0  7 bulan lalu
# 4  https://lh3.googleusercontent.com/a-/ALV-UjVt8...     3.0  setahun lalu
#
#                                              snippet  \
# 0  Dari luar tampak seperti rumah hantu. Tapi lih...
# 1  Unik. Kampus "heritage" pertama yang pernah sa...
# 2  Universitasnya sangat bagus, tapi lebih diperh...
# 3  Hati-hati dengan dosen gadungan yang bernama "...
# 4  Sementara 3 bintang dulu ya min.\nMin, calon m...
#
#                                               images local_guide
# 0  ['https://lh5.googleusercontent.com/p/AF1QipNj...        True
# 1  ['https://lh5.googleusercontent.com/p/AF1QipOw...        True
# 2                                                NaN        True
# 3                                                NaN        True
# 4                                                NaN        True

# %%
# drop the columns
df = df.drop(columns=['page', 'link', 'thumbnail', 'date', 'images', 'local_guide'], axis=1)
df.head()
# Out:
#                     name  rating  \
# 0  Firdaus Agil Prasetyo     5.0
# 1              Miftah NG     5.0
# 2       Hafiz Nafi'uddin     3.0
# 3        Chandra Bintang     1.0
# 4             Wandy Bear     3.0
#
#                                              snippet
# 0  Dari luar tampak seperti rumah hantu. Tapi lih...
# 1  Unik. Kampus "heritage" pertama yang pernah sa...
# 2  Universitasnya sangat bagus, tapi lebih diperh...
# 3  Hati-hati dengan dosen gadungan yang bernama "...
# 4  Sementara 3 bintang dulu ya min.\nMin, calon m...

# %% [markdown]
# ## Convert to lowercase

# %%
df['temp_text'] = df['snippet'].str.lower()
df.head()
# Out:
#                     name  rating  \
# 0  Firdaus Agil Prasetyo     5.0
# 1              Miftah NG     5.0
# 2       Hafiz Nafi'uddin     3.0
# 3        Chandra Bintang     1.0
# 4             Wandy Bear     3.0
#
#                                              snippet  \
# 0  Dari luar tampak seperti rumah hantu. Tapi lih...
# 1  Unik. Kampus "heritage" pertama yang pernah sa...
# 2  Universitasnya sangat bagus, tapi lebih diperh...
# 3  Hati-hati dengan dosen gadungan yang bernama "...
# 4  Sementara 3 bintang dulu ya min.\nMin, calon m...
#
#                                            temp_text
# 0  dari luar tampak seperti rumah hantu. tapi lih...
# 1  unik. kampus "heritage" pertama yang pernah sa...
# 2  universitasnya sangat bagus, tapi lebih diperh...
# 3  hati-hati dengan dosen gadungan yang bernama "...
# 4  sementara 3 bintang dulu ya min.\nmin, calon m...

# %% [markdown]
# ## Remove Missings Values

# %%
df.isnull().sum()
# Out:
# name           0
# rating         0
# snippet      139
# temp_text    139
# dtype: int64

# %%
df = df.dropna(subset=['temp_text'])
df.head()
# Out:
#                     name  rating  \
# 0  Firdaus Agil Prasetyo     5.0
# 1              Miftah NG     5.0
# 2       Hafiz Nafi'uddin     3.0
# 3        Chandra Bintang     1.0
# 4             Wandy Bear     3.0
#
#                                              snippet  \
# 0  Dari luar tampak seperti rumah hantu. Tapi lih...
# 1  Unik. Kampus "heritage" pertama yang pernah sa...
# 2  Universitasnya sangat bagus, tapi lebih diperh...
# 3  Hati-hati dengan dosen gadungan yang bernama "...
# 4  Sementara 3 bintang dulu ya min.\nMin, calon m...
#
#                                            temp_text
# 0  dari luar tampak seperti rumah hantu. tapi lih...
# 1  unik. kampus "heritage" pertama yang pernah sa...
# 2  universitasnya sangat bagus, tapi lebih diperh...
# 3  hati-hati dengan dosen gadungan yang bernama "...
# 4  sementara 3 bintang dulu ya min.\nmin, calon m...

# %%
df.isnull().sum()
# Out:
# name         0
# rating       0
# snippet      0
# temp_text    0
# dtype: int64

# %% [markdown]
# ## Menghapus Whitespace

# %%
def remove_extra_whitespace(text):
    # Menghapus spasi di awal dan akhir teks
    text = text.strip()
    # Menghapus spasi berlebih di tengah teks
    text = re.sub('\s+', ' ', text)
    return text

# Menerapkan fungsi pada kolom 'temp_text'
df['temp_text'] = df['temp_text'].apply(lambda x: remove_extra_whitespace(x))
df.head()
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\s'
# <>:5: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\hp\AppData\Local\Temp\ipykernel_6784\400237288.py:5: SyntaxWarning: invalid escape sequence '\s'
#   text = re.sub('\s+', ' ', text)
#                     name  rating  \
# 0  Firdaus Agil Prasetyo     5.0
# 1              Miftah NG     5.0
# 2       Hafiz Nafi'uddin     3.0
# 3        Chandra Bintang     1.0
# 4             Wandy Bear     3.0
#
#                                              snippet  \
# 0  Dari luar tampak seperti rumah hantu. Tapi lih...
# 1  Unik. Kampus "heritage" pertama yang pernah sa...
# 2  Universitasnya sangat bagus, tapi lebih diperh...
# 3  Hati-hati dengan dosen gadungan yang bernama "...
# 4  Sementara 3 bintang dulu ya min.\nMin, calon m...
#
#                                            temp_text
# 0  dari luar tampak seperti rumah hantu. tapi lih...
# 1  unik. kampus "heritage" pertama yang pernah sa...
# 2  universitasnya sangat bagus, tapi lebih diperh...
# 3  hati-hati dengan dosen gadungan yang bernama "...
# 4  sementara 3 bintang dulu ya min. min, calon ma...

# %% [markdown]
# ## Removal of Punctuations

# %%
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
def remove_punctuations(text):
    punctuations = string.punctuation
    return text.translate(str.maketrans('', '', punctuations))

# %%
df['temp_text'] = df['temp_text'].apply(lambda x: remove_punctuations(x))
df.head()
# Out:
#                     name  rating  \
# 0  Firdaus Agil Prasetyo     5.0
# 1              Miftah NG     5.0
# 2       Hafiz Nafi'uddin     3.0
# 3        Chandra Bintang     1.0
# 4             Wandy Bear     3.0
#
#                                              snippet  \
# 0  Dari luar tampak seperti rumah hantu. Tapi lih...
# 1  Unik. Kampus "heritage" pertama yang pernah sa...
# 2  Universitasnya sangat bagus, tapi lebih diperh...
# 3  Hati-hati dengan dosen gadungan yang bernama "...
# 4  Sementara 3 bintang dulu ya min.\nMin, calon m...
#
#                                            temp_text
# 0  dari luar tampak seperti rumah hantu tapi liha...
# 1  unik kampus heritage pertama yang pernah saya ...
# 2  universitasnya sangat bagus tapi lebih diperha...
# 3  hatihati dengan dosen gadungan yang bernama ok...
# 4  sementara 3 bintang dulu ya min min calon maha...

# %% [markdown]
# ## Normalisasi Teks

# %%
# Kamus slang dan kata yang sudah dinormalisasi
slang_dict = {
    "gak": "tidak",
    "u": "you",
    "yg": "yang",
    "kalo": "kalau",
    "aja": "saja",
    "tdk": "tidak",
    "bgt": "banget",
    "dgn": "dengan",
    "dr": "dari",
    "dlm": "dalam",
    "sbg": "sebagai",
    "spt": "seperti",
    "utk": "untuk",
    "krn": "karena",
    "tp": "tapi",
    "jd": "jadi",
    "sy": "saya",
    "dg": "dengan",
    "trs": "terus",
    "sm": "sama",
    "pd": "pada",
    "blm": "belum",
    "sdh": "sudah",
    "td": "tadi",
    "lg": "lagi",
    "gmn": "gimana",
    "knp": "kenapa",
    "dpt": "dapat",
    "bbrp": "beberapa",
    "dl": "dulu",
    "kl": "kalau",
    "tmn": "teman",
    "msh": "masih",
    "syg": "sayang",
    "cm": "cuma",
    "bs": "bisa",
    "jg": "juga",
    "org": "orang",
    "bkn": "bukan",
    "bbrp": "beberapa",
    "dpt": "dapat",
    "dgn": "dengan",
    "dr": "dari",
    "gmn": "gimana",
    "hrs": "harus",
    "jgn": "jangan",
    "krn": "karena",
    "lg": "lagi",
    "pd": "pada",
    "sdh": "sudah",
    "sm": "sama",
    "tdk": "tidak",
    "tp": "tapi",
    "utk": "untuk",
    "yg": "yang"
}

# Fungsi untuk mengganti kata slang dengan kata yang sudah dinormalisasi
def normalize_text(text):
    words = text.split()
    normalized_words = [slang_dict.get(word, word) for word in words]
    return " ".join(normalized_words)

# Menerapkan normalisasi pada kolom temp_text
df['temp_text'] = df['temp_text'].apply(lambda x: normalize_text(x))
df.head(10)
# Out:
#                     name  rating  \
# 0  Firdaus Agil Prasetyo     5.0
# 1              Miftah NG     5.0
# 2       Hafiz Nafi'uddin     3.0
# 3        Chandra Bintang     1.0
# 4             Wandy Bear     3.0
# 5            Fajar Rifat     2.0
# 6          Justin Hubner     1.0
# 7            MiawLegenD_     1.0
# 8       thandmustedi Pur     1.0
# 9             Nurtoha Mr     4.0
#
#                                              snippet  \
# 0  Dari luar tampak seperti rumah hantu. Tapi lih...
# 1  Unik. Kampus "heritage" pertama yang pernah sa...
# 2  Universitasnya sangat bagus, tapi lebih diperh...
# 3  Hati-hati dengan dosen gadungan yang bernama "...
# 4  Sementara 3 bintang dulu ya min.\nMin, calon m...
# 5  Jalan masuk untuk motor ke kampus B paving nya...
# 6  Dapat Orderan Go Ride Atas Nama "Amelia S" pad...
# 7  Kekurangan yang ada :\n1. Parkiran\nGa ada par...
# 8  1. Syarat pendaftaran kurang terperinci dan si...
# 9  Lokasinya cukup Sejuk, asri dan bersih, banyak...
#
#                                            temp_text
# 0  dari luar tampak seperti rumah hantu tapi liha...
# 1  unik kampus heritage pertama yang pernah saya ...
# 2  universitasnya sangat bagus tapi lebih diperha...
# 3  hatihati dengan dosen gadungan yang bernama ok...
# 4  sementara 3 bintang dulu ya min min calon maha...
# 5  jalan masuk untuk motor ke kampus b paving nya...
# 6  dapat orderan go ride atas nama amelia s pada ...
# 7  kekurangan yang ada 1 parkiran ga ada parkiran...
# 8  1 syarat pendaftaran kurang terperinci dan sis...
# 9  lokasinya cukup sejuk asri dan bersih banyak p...

# %% [markdown]
# ## Removal of Stopwords

# %%
from nltk.corpus import stopwords
", ".join(stopwords.words('indonesian'))
# Out:
# 'ada, adalah, adanya, adapun, agak, agaknya, agar, akan, akankah, akhir, akhiri, akhirnya, aku, akulah, amat, amatlah, anda, andalah, antar, antara, antaranya, apa, apaan, apabila, apakah, apalagi, apatah, artinya, asal, asalkan, atas, atau, ataukah, ataupun, awal, awalnya, bagai, bagaikan, bagaimana, bagaimanakah, bagaimanapun, bagi, bagian, bahkan, bahwa, bahwasanya, baik, bakal, bakalan, balik, banyak, bapak, baru, bawah, beberapa, begini, beginian, beginikah, beginilah, begitu, begitukah, begitulah, begitupun, bekerja, belakang, belakangan, belum, belumlah, benar, benarkah, benarlah, berada, berakhir, berakhirlah, berakhirnya, berapa, berapakah, berapalah, berapapun, berarti, berawal, berbagai, berdatangan, beri, berikan, berikut, berikutnya, berjumlah, berkali-kali, berkata, berkehendak, berkeinginan, berkenaan, berlainan, berlalu, berlangsung, berlebihan, bermacam, bermacam-macam, bermaksud, bermula, bersama, bersama-sama, bersiap, bersiap-siap, bertanya, bertanya-tanya, berturut, berturut-turut, bertutur, berujar, berupa, besar, betul, betulkah, biasa, biasanya, bila, bilakah, bisa, bisakah, boleh, bolehkah, bolehlah, buat, bukan, bukankah, bukanlah, bukannya, bulan, bung, cara, caranya, cukup, cukupkah, cukuplah, cuma, dahulu, dalam, dan, dapat, dari, daripada, datang, dekat, demi, demikian, demikianlah, dengan, depan, di, dia, diakhiri, diakhirinya, dialah, diantara, diantaranya, diberi, diberikan, diberikannya, dibuat, dibuatnya, didapat, didatangkan, digunakan, diibaratkan, diibaratkannya, diingat, diingatkan, diinginkan, dijawab, dijelaskan, dijelaskannya, dikarenakan, dikatakan, dikatakannya, dikerjakan, diketahui, diketahuinya, dikira, dilakukan, dilalui, dilihat, dimaksud, dimaksudkan, dimaksudkannya, dimaksudnya, diminta, dimintai, dimisalkan, dimulai, dimulailah, dimulainya, dimungkinkan, dini, dipastikan, diperbuat, diperbuatnya, dipergunakan, diperkirakan, diperlihatkan, diperlukan, diperlukannya, dipersoalkan, dipertanyakan, dipunyai, diri, dirinya, disampaikan, disebut, disebutkan, disebutkannya, disini, disinilah, ditambahkan, ditandaskan, ditanya, ditanyai, ditanyakan, ditegaskan, ditujukan, ditunjuk, ditunjuki, ditunjukkan, ditunjukkannya, ditunjuknya, dituturkan, dituturkannya, diucapkan, diucapkannya, diungkapkan, dong, dua, dulu, empat, enggak, enggaknya, entah, entahlah, guna, gunakan, hal, hampir, hanya, hanyalah, hari, harus, haruslah, harusnya, hendak, hendaklah, hendaknya, hingga, ia, ialah, ibarat, ibaratkan, ibaratnya, ibu, ikut, ingat, ingat-ingat, ingin, inginkah, inginkan, ini, inikah, inilah, itu, itukah, itulah, jadi, jadilah, jadinya, jangan, jangankan, janganlah, jauh, jawab, jawaban, jawabnya, jelas, jelaskan, jelaslah, jelasnya, jika, jikalau, juga, jumlah, jumlahnya, justru, kala, kalau, kalaulah, kalaupun, kalian, kami, kamilah, kamu, kamulah, kan, kapan, kapankah, kapanpun, karena, karenanya, kasus, kata, katakan, katakanlah, katanya, ke, keadaan, kebetulan, kecil, kedua, keduanya, keinginan, kelamaan, kelihatan, kelihatannya, kelima, keluar, kembali, kemudian, kemungkinan, kemungkinannya, kenapa, kepada, kepadanya, kesampaian, keseluruhan, keseluruhannya, keterlaluan, ketika, khususnya, kini, kinilah, kira, kira-kira, kiranya, kita, kitalah, kok, kurang, lagi, lagian, lah, lain, lainnya, lalu, lama, lamanya, lanjut, lanjutnya, lebih, lewat, lima, luar, macam, maka, makanya, makin, malah, malahan, mampu, mampukah, mana, manakala, manalagi, masa, masalah, masalahnya, masih, masihkah, masing, masing-masing, mau, maupun, melainkan, melakukan, melalui, melihat, melihatnya, memang, memastikan, memberi, memberikan, membuat, memerlukan, memihak, meminta, memintakan, memisalkan, memperbuat, mempergunakan, memperkirakan, memperlihatkan, mempersiapkan, mempersoalkan, mempertanyakan, mempunyai, memulai, memungkinkan, menaiki, menambahkan, menandaskan, menanti, menanti-nanti, menantikan, menanya, menanyai, menanyakan, mendapat, mendapatkan, mendatang, mendatangi, mendatangkan, menegaskan, meng ...

# %%
from nltk.corpus import stopwords

STOPWORDS = set(stopwords.words('indonesian'))
def remove_stopwords(text):
    return " ".join([word for word in text.split() if word not in STOPWORDS])

# %%
df['temp_text'] = df['temp_text'].apply(lambda x: remove_stopwords(x))
df.head()
# Out:
#                     name  rating  \
# 0  Firdaus Agil Prasetyo     5.0
# 1              Miftah NG     5.0
# 2       Hafiz Nafi'uddin     3.0
# 3        Chandra Bintang     1.0
# 4             Wandy Bear     3.0
#
#                                              snippet  \
# 0  Dari luar tampak seperti rumah hantu. Tapi lih...
# 1  Unik. Kampus "heritage" pertama yang pernah sa...
# 2  Universitasnya sangat bagus, tapi lebih diperh...
# 3  Hati-hati dengan dosen gadungan yang bernama "...
# 4  Sementara 3 bintang dulu ya min.\nMin, calon m...
#
#                                            temp_text
# 0  rumah hantu lihatlah masuk sempurna tempatnya ...
# 1  unik kampus heritage datangi area bekas pabrik...
# 2  universitasnya bagus diperhatikan dikampus 2 j...
# 3  hatihati dosen gadungan bernama oktavian zulfi...
# 4  3 bintang ya min min calon mahasiswamahasiswi ...

# %% [markdown]
# ## !!!Removal of Frequent Words

# %%
# Menghapus semua kata "nya" yang berdiri sendiri dalam kolom temp_text
df['temp_text'] = df['temp_text'].apply(lambda text: ' '.join([word for word in text.split() if word != 'nya']))

df.head()
# Out:
#                     name  rating  \
# 0  Firdaus Agil Prasetyo     5.0
# 1              Miftah NG     5.0
# 2       Hafiz Nafi'uddin     3.0
# 3        Chandra Bintang     1.0
# 4             Wandy Bear     3.0
#
#                                              snippet  \
# 0  Dari luar tampak seperti rumah hantu. Tapi lih...
# 1  Unik. Kampus "heritage" pertama yang pernah sa...
# 2  Universitasnya sangat bagus, tapi lebih diperh...
# 3  Hati-hati dengan dosen gadungan yang bernama "...
# 4  Sementara 3 bintang dulu ya min.\nMin, calon m...
#
#                                            temp_text
# 0  rumah hantu lihatlah masuk sempurna tempatnya ...
# 1  unik kampus heritage datangi area bekas pabrik...
# 2  universitasnya bagus diperhatikan dikampus 2 j...
# 3  hatihati dosen gadungan bernama oktavian zulfi...
# 4  3 bintang ya min min calon mahasiswamahasiswi ...

# %%
from collections import Counter
word_count = Counter()
for text in df['temp_text']:
    for word in text.split():
        word_count[word] += 1
        
word_count.most_common(10)
# Out:
# [('kampus', 33),
#  ('bagus', 11),
#  ('gresik', 10),
#  ('mahasiswa', 8),
#  ('indonesia', 7),
#  ('ac', 6),
#  ('ga', 6),
#  ('masuk', 5),
#  ('kuliah', 5),
#  ('semen', 5)]

# %%
df.head()
# Out:
#                     name  rating  \
# 0  Firdaus Agil Prasetyo     5.0
# 1              Miftah NG     5.0
# 2       Hafiz Nafi'uddin     3.0
# 3        Chandra Bintang     1.0
# 4             Wandy Bear     3.0
#
#                                              snippet  \
# 0  Dari luar tampak seperti rumah hantu. Tapi lih...
# 1  Unik. Kampus "heritage" pertama yang pernah sa...
# 2  Universitasnya sangat bagus, tapi lebih diperh...
# 3  Hati-hati dengan dosen gadungan yang bernama "...
# 4  Sementara 3 bintang dulu ya min.\nMin, calon m...
#
#                                            temp_text
# 0  rumah hantu lihatlah masuk sempurna tempatnya ...
# 1  unik kampus heritage datangi area bekas pabrik...
# 2  universitasnya bagus diperhatikan dikampus 2 j...
# 3  hatihati dosen gadungan bernama oktavian zulfi...
# 4  3 bintang ya min min calon mahasiswamahasiswi ...

# %%
# FREQUENT_WORDS = set(word for (word, wc) in word_count.most_common(3))
# def remove_freq_words(text):
#     return " ".join([word for word in text.split() if word not in FREQUENT_WORDS])

# %%
# df['temp_text'] = df['temp_text'].apply(lambda x: remove_freq_words(x))
# df.head()

# %% [markdown]
# ## Removal of Rare Words

# %%
# This cell should be moved after CELL INDEX 22
RARE_WORDS = set(word for (word, wc) in word_count.most_common()[:-10:-1])
print(RARE_WORDS)
# Out:
# {'private', 'dabest💕👌', 'stimsi', 'facilities', 'tekkim', 'reputable', 'people', 'homy', 'niceeee'}

# %%
def remove_rare_words(text):
    return " ".join([word for word in text.split() if word not in RARE_WORDS])

# %%
df['temp_text'] = df['temp_text'].apply(lambda x: remove_rare_words(x))
df.head()
# Out:
#                     name  rating  \
# 0  Firdaus Agil Prasetyo     5.0
# 1              Miftah NG     5.0
# 2       Hafiz Nafi'uddin     3.0
# 3        Chandra Bintang     1.0
# 4             Wandy Bear     3.0
#
#                                              snippet  \
# 0  Dari luar tampak seperti rumah hantu. Tapi lih...
# 1  Unik. Kampus "heritage" pertama yang pernah sa...
# 2  Universitasnya sangat bagus, tapi lebih diperh...
# 3  Hati-hati dengan dosen gadungan yang bernama "...
# 4  Sementara 3 bintang dulu ya min.\nMin, calon m...
#
#                                            temp_text
# 0  rumah hantu lihatlah masuk sempurna tempatnya ...
# 1  unik kampus heritage datangi area bekas pabrik...
# 2  universitasnya bagus diperhatikan dikampus 2 j...
# 3  hatihati dosen gadungan bernama oktavian zulfi...
# 4  3 bintang ya min min calon mahasiswamahasiswi ...

# %% [markdown]
# ## Removal of Special characters

# %%
import re
def remove_spl_chars(text):
    text = re.sub('[^a-zA-Z0-9]', ' ', text)
    text = re.sub('\s+', ' ', text)
    return text
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\s'
# <>:4: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\hp\AppData\Local\Temp\ipykernel_6784\688201358.py:4: SyntaxWarning: invalid escape sequence '\s'
#   text = re.sub('\s+', ' ', text)

# %%
df['temp_text'] = df['temp_text'].apply(lambda x: remove_spl_chars(x))
df.head()
# Out:
#                     name  rating  \
# 0  Firdaus Agil Prasetyo     5.0
# 1              Miftah NG     5.0
# 2       Hafiz Nafi'uddin     3.0
# 3        Chandra Bintang     1.0
# 4             Wandy Bear     3.0
#
#                                              snippet  \
# 0  Dari luar tampak seperti rumah hantu. Tapi lih...
# 1  Unik. Kampus "heritage" pertama yang pernah sa...
# 2  Universitasnya sangat bagus, tapi lebih diperh...
# 3  Hati-hati dengan dosen gadungan yang bernama "...
# 4  Sementara 3 bintang dulu ya min.\nMin, calon m...
#
#                                            temp_text
# 0  rumah hantu lihatlah masuk sempurna tempatnya ...
# 1  unik kampus heritage datangi area bekas pabrik...
# 2  universitasnya bagus diperhatikan dikampus 2 j...
# 3  hatihati dosen gadungan bernama oktavian zulfi...
# 4  3 bintang ya min min calon mahasiswamahasiswi ...

# %% [markdown]
# ## Stemming

# %%
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory

# Membuat stemmer bahasa Indonesia
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# Fungsi stemming
def stem_words(text):
    return stemmer.stem(text)

# %%
# Menerapkan stemming pada kolom temp_text
df['stemmed_text'] = df['temp_text'].apply(lambda x: stem_words(x))
df.head()
# Out:
#                     name  rating  \
# 0  Firdaus Agil Prasetyo     5.0
# 1              Miftah NG     5.0
# 2       Hafiz Nafi'uddin     3.0
# 3        Chandra Bintang     1.0
# 4             Wandy Bear     3.0
#
#                                              snippet  \
# 0  Dari luar tampak seperti rumah hantu. Tapi lih...
# 1  Unik. Kampus "heritage" pertama yang pernah sa...
# 2  Universitasnya sangat bagus, tapi lebih diperh...
# 3  Hati-hati dengan dosen gadungan yang bernama "...
# 4  Sementara 3 bintang dulu ya min.\nMin, calon m...
#
#                                            temp_text  \
# 0  rumah hantu lihatlah masuk sempurna tempatnya ...
# 1  unik kampus heritage datangi area bekas pabrik...
# 2  universitasnya bagus diperhatikan dikampus 2 j...
# 3  hatihati dosen gadungan bernama oktavian zulfi...
# 4  3 bintang ya min min calon mahasiswamahasiswi ...
#
#                                         stemmed_text
# 0  rumah hantu lihat masuk sempurna tempat bagus ...
# 1  unik kampus heritage datang area bekas pabrik ...
# 2  universitas bagus perhati kampus 2 jalan licin...
# 3  hatihati dosen gadungan nama oktavian zulfiky ...
# 4  3 bintang ya min min calon mahasiswamahasiswi ...

# %% [markdown]
# ## Lemmatization & POS Tagging

# %%
from nltk import pos_tag
from nltk.corpus import wordnet
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()
wordnet_map = {"N":wordnet.NOUN, "V": wordnet.VERB, "J": wordnet.ADJ, "R": wordnet.ADV}

def lemmatize_words(text):
    # find pos tags
    pos_text = pos_tag(text.split())
    return " ".join([lemmatizer.lemmatize(word, wordnet_map.get(pos[0], wordnet.NOUN)) for word, pos in pos_text])

# %%
from nltk.corpus import wordnet

wordnet.NOUN
# Out:
# 'n'

# %%
# import nltk
# nltk.download('averaged_perceptron_tagger')

# df['lemmatized_text'] = df['temp_text'].apply(lambda x: lemmatize_words(x))
# df.head()

# %%
df.sample(frac=1).head(10)
# Out:
#                            name  rating  \
# 72              Andi Zulfikar D     5.0
# 56              fatimatus zahra     5.0
# 71                 Ahmad Asrofi     5.0
# 34                 Fahmi Nandip     5.0
# 19  Fadhilah Dwiestri Handayani     5.0
# 31                 LUKE Lifting     5.0
# 27                   Ida Silvia     5.0
# 15                Vardian Bagus     5.0
# 44               Carina Jihadda     5.0
# 33                Copler Madura     5.0
#
#                                               snippet  \
# 72                             Crafting the Excellent
# 56                                             mantap
# 71                                               good
# 34                       Tempatnya adem, asri, sejuk.
# 19  Termasuk kampus terbaik di Gresik, dengan nuan...
# 31                 Universitas terbaik di kota gresik
# 27  Bangga jadi bagian kampus ini 👍 keep crafting ...
# 15  Kampus UISI adalah Campus kebanggaan anak kami...
# 44                      Universitas yang sangat bagus
# 33                                        sangat puas
#
#                                             temp_text  \
# 72                             crafting the excellent
# 56                                             mantap
# 71                                               good
# 34                          tempatnya adem asri sejuk
# 19  kampus terbaik gresik nuansa industrial dapet ...
# 31                    universitas terbaik kota gresik
# 27          bangga kampus keep crafting the excellent
# 15  kampus uisi campus kebanggaan anak genersi mud...
# 44                                  universitas bagus
# 33                                               puas
#
#                                          stemmed_text
# 72                             crafting the excellent
# 56                                             mantap
# 71                                               good
# 34                             tempat adem asri sejuk
# 19  kampus baik gresik nuansa industrial dapet banget
# 31                       universitas baik kota gresik
# 27          bangga kampus keep crafting the excellent
# 15  kampus uis campus bangga anak genersi muda usa...
# 44                                  universitas bagus
# 33                                               puas

# %% [markdown]
# ## Tokenization

# %%
df.head()
# Out:
#                     name  rating  \
# 0  Firdaus Agil Prasetyo     5.0
# 1              Miftah NG     5.0
# 2       Hafiz Nafi'uddin     3.0
# 3        Chandra Bintang     1.0
# 4             Wandy Bear     3.0
#
#                                              snippet  \
# 0  Dari luar tampak seperti rumah hantu. Tapi lih...
# 1  Unik. Kampus "heritage" pertama yang pernah sa...
# 2  Universitasnya sangat bagus, tapi lebih diperh...
# 3  Hati-hati dengan dosen gadungan yang bernama "...
# 4  Sementara 3 bintang dulu ya min.\nMin, calon m...
#
#                                            temp_text  \
# 0  rumah hantu lihatlah masuk sempurna tempatnya ...
# 1  unik kampus heritage datangi area bekas pabrik...
# 2  universitasnya bagus diperhatikan dikampus 2 j...
# 3  hatihati dosen gadungan bernama oktavian zulfi...
# 4  3 bintang ya min min calon mahasiswamahasiswi ...
#
#                                         stemmed_text
# 0  rumah hantu lihat masuk sempurna tempat bagus ...
# 1  unik kampus heritage datang area bekas pabrik ...
# 2  universitas bagus perhati kampus 2 jalan licin...
# 3  hatihati dosen gadungan nama oktavian zulfiky ...
# 4  3 bintang ya min min calon mahasiswamahasiswi ...

# %%
df.isnull().sum()
# Out:
# name            0
# rating          0
# snippet         0
# temp_text       0
# stemmed_text    0
# dtype: int64

# %%
from nltk.tokenize import word_tokenize

# Tokenisasi
df['tokenized_text'] = df['stemmed_text'].apply(lambda x: word_tokenize(x))
df.head()
# Out:
#                     name  rating  \
# 0  Firdaus Agil Prasetyo     5.0
# 1              Miftah NG     5.0
# 2       Hafiz Nafi'uddin     3.0
# 3        Chandra Bintang     1.0
# 4             Wandy Bear     3.0
#
#                                              snippet  \
# 0  Dari luar tampak seperti rumah hantu. Tapi lih...
# 1  Unik. Kampus "heritage" pertama yang pernah sa...
# 2  Universitasnya sangat bagus, tapi lebih diperh...
# 3  Hati-hati dengan dosen gadungan yang bernama "...
# 4  Sementara 3 bintang dulu ya min.\nMin, calon m...
#
#                                            temp_text  \
# 0  rumah hantu lihatlah masuk sempurna tempatnya ...
# 1  unik kampus heritage datangi area bekas pabrik...
# 2  universitasnya bagus diperhatikan dikampus 2 j...
# 3  hatihati dosen gadungan bernama oktavian zulfi...
# 4  3 bintang ya min min calon mahasiswamahasiswi ...
#
#                                         stemmed_text  \
# 0  rumah hantu lihat masuk sempurna tempat bagus ...
# 1  unik kampus heritage datang area bekas pabrik ...
# 2  universitas bagus perhati kampus 2 jalan licin...
# 3  hatihati dosen gadungan nama oktavian zulfiky ...
# 4  3 bintang ya min min calon mahasiswamahasiswi ...
#
#                                       tokenized_text
# 0  [rumah, hantu, lihat, masuk, sempurna, tempat,...
# 1  [unik, kampus, heritage, datang, area, bekas, ...
# 2  [universitas, bagus, perhati, kampus, 2, jalan...
# 3  [hatihati, dosen, gadungan, nama, oktavian, zu...
# 4  [3, bintang, ya, min, min, calon, mahasiswamah...

# %%
# Cleaned text
df['cleaned_text'] = df['tokenized_text']
df.head()
# Out:
#                     name  rating  \
# 0  Firdaus Agil Prasetyo     5.0
# 1              Miftah NG     5.0
# 2       Hafiz Nafi'uddin     3.0
# 3        Chandra Bintang     1.0
# 4             Wandy Bear     3.0
#
#                                              snippet  \
# 0  Dari luar tampak seperti rumah hantu. Tapi lih...
# 1  Unik. Kampus "heritage" pertama yang pernah sa...
# 2  Universitasnya sangat bagus, tapi lebih diperh...
# 3  Hati-hati dengan dosen gadungan yang bernama "...
# 4  Sementara 3 bintang dulu ya min.\nMin, calon m...
#
#                                            temp_text  \
# 0  rumah hantu lihatlah masuk sempurna tempatnya ...
# 1  unik kampus heritage datangi area bekas pabrik...
# 2  universitasnya bagus diperhatikan dikampus 2 j...
# 3  hatihati dosen gadungan bernama oktavian zulfi...
# 4  3 bintang ya min min calon mahasiswamahasiswi ...
#
#                                         stemmed_text  \
# 0  rumah hantu lihat masuk sempurna tempat bagus ...
# 1  unik kampus heritage datang area bekas pabrik ...
# 2  universitas bagus perhati kampus 2 jalan licin...
# 3  hatihati dosen gadungan nama oktavian zulfiky ...
# 4  3 bintang ya min min calon mahasiswamahasiswi ...
#
#                                       tokenized_text  \
# 0  [rumah, hantu, lihat, masuk, sempurna, tempat,...
# 1  [unik, kampus, heritage, datang, area, bekas, ...
# 2  [universitas, bagus, perhati, kampus, 2, jalan...
# 3  [hatihati, dosen, gadungan, nama, oktavian, zu...
# 4  [3, bintang, ya, min, min, calon, mahasiswamah...
#
#                                         cleaned_text
# 0  [rumah, hantu, lihat, masuk, sempurna, tempat,...
# 1  [unik, kampus, heritage, datang, area, bekas, ...
# 2  [universitas, bagus, perhati, kampus, 2, jalan...
# 3  [hatihati, dosen, gadungan, nama, oktavian, zu...
# 4  [3, bintang, ya, min, min, calon, mahasiswamah...

# %%
import os

try:
	# Save the dataframe to a CSV file
	df.to_csv(output_path, index=False)
	print(f"DataFrame successfully saved to {output_path}")
except Exception as e:
	print(f"An error occurred: {e}")
# Out:
# DataFrame successfully saved to ../../dataset/cleaned-data/UISI_Reviews_cleaned.csv
