# %% [markdown]
# # **Preprocessing | Universitas Pertamina (UPer)**

# %% [markdown]
# # Text Preprocessing (Clean Data)

# %%
import pandas as pd
import string
import re
df = pd.read_csv('../../dataset/UPer_reviews.csv')

output_path = '../../dataset/cleaned-data/UPer_Reviews_cleaned.csv'

df.head()
# Out:
#    page               name                                               link  \
# 0     1              Te Ir  https://www.google.com/maps/contrib/1132768062...
# 1     1               RHDN  https://www.google.com/maps/contrib/1155154390...
# 2     1       Mega Safitri  https://www.google.com/maps/contrib/1039782495...
# 3     1  Muhammad Zidane A  https://www.google.com/maps/contrib/1166708707...
# 4     1        Fahmi Amhar  https://www.google.com/maps/contrib/1122985339...
#
#                                            thumbnail  rating          date  \
# 0  https://lh3.googleusercontent.com/a-/ALV-UjUpa...     4.0  sebulan lalu
# 1  https://lh3.googleusercontent.com/a-/ALV-UjWqG...     4.0  7 bulan lalu
# 2  https://lh3.googleusercontent.com/a/ACg8ocJH8h...     3.0  sebulan lalu
# 3  https://lh3.googleusercontent.com/a-/ALV-UjWL4...     5.0  7 bulan lalu
# 4  https://lh3.googleusercontent.com/a-/ALV-UjUOg...     4.0  6 tahun lalu
#
#                                              snippet  \
# 0  Universitas yang menjadi bagian Pertamina (per...
# 1  Kampus nya cukup besar, lokasi pinggir jalan s...
# 2  Kami pilih kampus ini dg harapan setelah lulus...
# 3  walaupun terbilang masih baru, tetapi kampus i...
# 4  Campus ini memiliki sarana yang cukup lengkap,...
#
#                                               images local_guide
# 0  ['https://lh5.googleusercontent.com/p/AF1QipOA...        True
# 1  ['https://lh5.googleusercontent.com/p/AF1QipPu...        True
# 2                                                NaN         NaN
# 3  ['https://lh5.googleusercontent.com/p/AF1QipPI...        True
# 4  ['https://lh5.googleusercontent.com/p/AF1QipNr...        True

# %%
# drop the columns
df = df.drop(columns=['page', 'link', 'thumbnail', 'date', 'images', 'local_guide'], axis=1)
df.head()
# Out:
#                 name  rating  \
# 0              Te Ir     4.0
# 1               RHDN     4.0
# 2       Mega Safitri     3.0
# 3  Muhammad Zidane A     5.0
# 4        Fahmi Amhar     4.0
#
#                                              snippet
# 0  Universitas yang menjadi bagian Pertamina (per...
# 1  Kampus nya cukup besar, lokasi pinggir jalan s...
# 2  Kami pilih kampus ini dg harapan setelah lulus...
# 3  walaupun terbilang masih baru, tetapi kampus i...
# 4  Campus ini memiliki sarana yang cukup lengkap,...

# %% [markdown]
# ## Convert to lowercase

# %%
df['temp_text'] = df['snippet'].str.lower()
df.head()
# Out:
#                 name  rating  \
# 0              Te Ir     4.0
# 1               RHDN     4.0
# 2       Mega Safitri     3.0
# 3  Muhammad Zidane A     5.0
# 4        Fahmi Amhar     4.0
#
#                                              snippet  \
# 0  Universitas yang menjadi bagian Pertamina (per...
# 1  Kampus nya cukup besar, lokasi pinggir jalan s...
# 2  Kami pilih kampus ini dg harapan setelah lulus...
# 3  walaupun terbilang masih baru, tetapi kampus i...
# 4  Campus ini memiliki sarana yang cukup lengkap,...
#
#                                            temp_text
# 0  universitas yang menjadi bagian pertamina (per...
# 1  kampus nya cukup besar, lokasi pinggir jalan s...
# 2  kami pilih kampus ini dg harapan setelah lulus...
# 3  walaupun terbilang masih baru, tetapi kampus i...
# 4  campus ini memiliki sarana yang cukup lengkap,...

# %% [markdown]
# ## Remove Missings Values

# %%
df.isnull().sum()
# Out:
# name           0
# rating         0
# snippet      554
# temp_text    554
# dtype: int64

# %%
df = df.dropna(subset=['temp_text'])
df.head()
# Out:
#                 name  rating  \
# 0              Te Ir     4.0
# 1               RHDN     4.0
# 2       Mega Safitri     3.0
# 3  Muhammad Zidane A     5.0
# 4        Fahmi Amhar     4.0
#
#                                              snippet  \
# 0  Universitas yang menjadi bagian Pertamina (per...
# 1  Kampus nya cukup besar, lokasi pinggir jalan s...
# 2  Kami pilih kampus ini dg harapan setelah lulus...
# 3  walaupun terbilang masih baru, tetapi kampus i...
# 4  Campus ini memiliki sarana yang cukup lengkap,...
#
#                                            temp_text
# 0  universitas yang menjadi bagian pertamina (per...
# 1  kampus nya cukup besar, lokasi pinggir jalan s...
# 2  kami pilih kampus ini dg harapan setelah lulus...
# 3  walaupun terbilang masih baru, tetapi kampus i...
# 4  campus ini memiliki sarana yang cukup lengkap,...

# %%
df.isnull().sum()
# Out:
# name         0
# rating       0
# snippet      0
# temp_text    0
# dtype: int64

# %% [markdown]
# ## Menghapus Whitespace

# %%
def remove_extra_whitespace(text):
    # Menghapus spasi di awal dan akhir teks
    text = text.strip()
    # Menghapus spasi berlebih di tengah teks
    text = re.sub('\s+', ' ', text)
    return text

# Menerapkan fungsi pada kolom 'temp_text'
df['temp_text'] = df['temp_text'].apply(lambda x: remove_extra_whitespace(x))
df.head()
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\s'
# <>:5: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\hp\AppData\Local\Temp\ipykernel_16812\400237288.py:5: SyntaxWarning: invalid escape sequence '\s'
#   text = re.sub('\s+', ' ', text)
#                 name  rating  \
# 0              Te Ir     4.0
# 1               RHDN     4.0
# 2       Mega Safitri     3.0
# 3  Muhammad Zidane A     5.0
# 4        Fahmi Amhar     4.0
#
#                                              snippet  \
# 0  Universitas yang menjadi bagian Pertamina (per...
# 1  Kampus nya cukup besar, lokasi pinggir jalan s...
# 2  Kami pilih kampus ini dg harapan setelah lulus...
# 3  walaupun terbilang masih baru, tetapi kampus i...
# 4  Campus ini memiliki sarana yang cukup lengkap,...
#
#                                            temp_text
# 0  universitas yang menjadi bagian pertamina (per...
# 1  kampus nya cukup besar, lokasi pinggir jalan s...
# 2  kami pilih kampus ini dg harapan setelah lulus...
# 3  walaupun terbilang masih baru, tetapi kampus i...
# 4  campus ini memiliki sarana yang cukup lengkap,...

# %% [markdown]
# ## Removal of Punctuations

# %%
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
def remove_punctuations(text):
    punctuations = string.punctuation
    return text.translate(str.maketrans('', '', punctuations))

# %%
df['temp_text'] = df['temp_text'].apply(lambda x: remove_punctuations(x))
df.head()
# Out:
#                 name  rating  \
# 0              Te Ir     4.0
# 1               RHDN     4.0
# 2       Mega Safitri     3.0
# 3  Muhammad Zidane A     5.0
# 4        Fahmi Amhar     4.0
#
#                                              snippet  \
# 0  Universitas yang menjadi bagian Pertamina (per...
# 1  Kampus nya cukup besar, lokasi pinggir jalan s...
# 2  Kami pilih kampus ini dg harapan setelah lulus...
# 3  walaupun terbilang masih baru, tetapi kampus i...
# 4  Campus ini memiliki sarana yang cukup lengkap,...
#
#                                            temp_text
# 0  universitas yang menjadi bagian pertamina pers...
# 1  kampus nya cukup besar lokasi pinggir jalan si...
# 2  kami pilih kampus ini dg harapan setelah lulus...
# 3  walaupun terbilang masih baru tetapi kampus in...
# 4  campus ini memiliki sarana yang cukup lengkap ...

# %% [markdown]
# ## Normalisasi Teks

# %%
# Kamus slang dan kata yang sudah dinormalisasi
slang_dict = {
    "gak": "tidak",
    "u": "you",
    "yg": "yang",
    "kalo": "kalau",
    "aja": "saja",
    "tdk": "tidak",
    "bgt": "banget",
    "dgn": "dengan",
    "dr": "dari",
    "dlm": "dalam",
    "sbg": "sebagai",
    "spt": "seperti",
    "utk": "untuk",
    "krn": "karena",
    "tp": "tapi",
    "jd": "jadi",
    "sy": "saya",
    "dg": "dengan",
    "trs": "terus",
    "sm": "sama",
    "pd": "pada",
    "blm": "belum",
    "sdh": "sudah",
    "td": "tadi",
    "lg": "lagi",
    "gmn": "gimana",
    "knp": "kenapa",
    "dpt": "dapat",
    "bbrp": "beberapa",
    "dl": "dulu",
    "kl": "kalau",
    "tmn": "teman",
    "msh": "masih",
    "syg": "sayang",
    "cm": "cuma",
    "bs": "bisa",
    "jg": "juga",
    "org": "orang",
    "bkn": "bukan",
    "bbrp": "beberapa",
    "dpt": "dapat",
    "dgn": "dengan",
    "dr": "dari",
    "gmn": "gimana",
    "hrs": "harus",
    "jgn": "jangan",
    "krn": "karena",
    "lg": "lagi",
    "pd": "pada",
    "sdh": "sudah",
    "sm": "sama",
    "tdk": "tidak",
    "tp": "tapi",
    "utk": "untuk",
    "yg": "yang"
}

# Fungsi untuk mengganti kata slang dengan kata yang sudah dinormalisasi
def normalize_text(text):
    words = text.split()
    normalized_words = [slang_dict.get(word, word) for word in words]
    return " ".join(normalized_words)

# Menerapkan normalisasi pada kolom temp_text
df['temp_text'] = df['temp_text'].apply(lambda x: normalize_text(x))
df.head(10)
# Out:
#                 name  rating  \
# 0              Te Ir     4.0
# 1               RHDN     4.0
# 2       Mega Safitri     3.0
# 3  Muhammad Zidane A     5.0
# 4        Fahmi Amhar     4.0
# 5      ares rahmawan     5.0
# 6      Frenda Fawzia     5.0
# 7              Nanda     5.0
# 8          Reginaldi     5.0
# 9             Caesar     5.0
#
#                                              snippet  \
# 0  Universitas yang menjadi bagian Pertamina (per...
# 1  Kampus nya cukup besar, lokasi pinggir jalan s...
# 2  Kami pilih kampus ini dg harapan setelah lulus...
# 3  walaupun terbilang masih baru, tetapi kampus i...
# 4  Campus ini memiliki sarana yang cukup lengkap,...
# 5  Tiket nya 75 ribu utk Olympic Size Pool. Clean...
# 6  Dulu terkenalnya dengan nama Pertamina Trainin...
# 7  Kampus yang bagus, fasilitas 90% lengkap, deka...
# 8  baguss universitasnyaa ,salam buat angel anak ...
# 9  Area Kampus Sangat Ramah Lingkungan. nuansa as...
#
#                                            temp_text
# 0  universitas yang menjadi bagian pertamina pers...
# 1  kampus nya cukup besar lokasi pinggir jalan si...
# 2  kami pilih kampus ini dengan harapan setelah l...
# 3  walaupun terbilang masih baru tetapi kampus in...
# 4  campus ini memiliki sarana yang cukup lengkap ...
# 5  tiket nya 75 ribu untuk olympic size pool clea...
# 6  dulu terkenalnya dengan nama pertamina trainin...
# 7  kampus yang bagus fasilitas 90 lengkap dekat d...
# 8  baguss universitasnyaa salam buat angel anak t...
# 9  area kampus sangat ramah lingkungan nuansa asr...

# %% [markdown]
# ## Removal of Stopwords

# %%
from nltk.corpus import stopwords
", ".join(stopwords.words('indonesian'))
# Out:
# 'ada, adalah, adanya, adapun, agak, agaknya, agar, akan, akankah, akhir, akhiri, akhirnya, aku, akulah, amat, amatlah, anda, andalah, antar, antara, antaranya, apa, apaan, apabila, apakah, apalagi, apatah, artinya, asal, asalkan, atas, atau, ataukah, ataupun, awal, awalnya, bagai, bagaikan, bagaimana, bagaimanakah, bagaimanapun, bagi, bagian, bahkan, bahwa, bahwasanya, baik, bakal, bakalan, balik, banyak, bapak, baru, bawah, beberapa, begini, beginian, beginikah, beginilah, begitu, begitukah, begitulah, begitupun, bekerja, belakang, belakangan, belum, belumlah, benar, benarkah, benarlah, berada, berakhir, berakhirlah, berakhirnya, berapa, berapakah, berapalah, berapapun, berarti, berawal, berbagai, berdatangan, beri, berikan, berikut, berikutnya, berjumlah, berkali-kali, berkata, berkehendak, berkeinginan, berkenaan, berlainan, berlalu, berlangsung, berlebihan, bermacam, bermacam-macam, bermaksud, bermula, bersama, bersama-sama, bersiap, bersiap-siap, bertanya, bertanya-tanya, berturut, berturut-turut, bertutur, berujar, berupa, besar, betul, betulkah, biasa, biasanya, bila, bilakah, bisa, bisakah, boleh, bolehkah, bolehlah, buat, bukan, bukankah, bukanlah, bukannya, bulan, bung, cara, caranya, cukup, cukupkah, cukuplah, cuma, dahulu, dalam, dan, dapat, dari, daripada, datang, dekat, demi, demikian, demikianlah, dengan, depan, di, dia, diakhiri, diakhirinya, dialah, diantara, diantaranya, diberi, diberikan, diberikannya, dibuat, dibuatnya, didapat, didatangkan, digunakan, diibaratkan, diibaratkannya, diingat, diingatkan, diinginkan, dijawab, dijelaskan, dijelaskannya, dikarenakan, dikatakan, dikatakannya, dikerjakan, diketahui, diketahuinya, dikira, dilakukan, dilalui, dilihat, dimaksud, dimaksudkan, dimaksudkannya, dimaksudnya, diminta, dimintai, dimisalkan, dimulai, dimulailah, dimulainya, dimungkinkan, dini, dipastikan, diperbuat, diperbuatnya, dipergunakan, diperkirakan, diperlihatkan, diperlukan, diperlukannya, dipersoalkan, dipertanyakan, dipunyai, diri, dirinya, disampaikan, disebut, disebutkan, disebutkannya, disini, disinilah, ditambahkan, ditandaskan, ditanya, ditanyai, ditanyakan, ditegaskan, ditujukan, ditunjuk, ditunjuki, ditunjukkan, ditunjukkannya, ditunjuknya, dituturkan, dituturkannya, diucapkan, diucapkannya, diungkapkan, dong, dua, dulu, empat, enggak, enggaknya, entah, entahlah, guna, gunakan, hal, hampir, hanya, hanyalah, hari, harus, haruslah, harusnya, hendak, hendaklah, hendaknya, hingga, ia, ialah, ibarat, ibaratkan, ibaratnya, ibu, ikut, ingat, ingat-ingat, ingin, inginkah, inginkan, ini, inikah, inilah, itu, itukah, itulah, jadi, jadilah, jadinya, jangan, jangankan, janganlah, jauh, jawab, jawaban, jawabnya, jelas, jelaskan, jelaslah, jelasnya, jika, jikalau, juga, jumlah, jumlahnya, justru, kala, kalau, kalaulah, kalaupun, kalian, kami, kamilah, kamu, kamulah, kan, kapan, kapankah, kapanpun, karena, karenanya, kasus, kata, katakan, katakanlah, katanya, ke, keadaan, kebetulan, kecil, kedua, keduanya, keinginan, kelamaan, kelihatan, kelihatannya, kelima, keluar, kembali, kemudian, kemungkinan, kemungkinannya, kenapa, kepada, kepadanya, kesampaian, keseluruhan, keseluruhannya, keterlaluan, ketika, khususnya, kini, kinilah, kira, kira-kira, kiranya, kita, kitalah, kok, kurang, lagi, lagian, lah, lain, lainnya, lalu, lama, lamanya, lanjut, lanjutnya, lebih, lewat, lima, luar, macam, maka, makanya, makin, malah, malahan, mampu, mampukah, mana, manakala, manalagi, masa, masalah, masalahnya, masih, masihkah, masing, masing-masing, mau, maupun, melainkan, melakukan, melalui, melihat, melihatnya, memang, memastikan, memberi, memberikan, membuat, memerlukan, memihak, meminta, memintakan, memisalkan, memperbuat, mempergunakan, memperkirakan, memperlihatkan, mempersiapkan, mempersoalkan, mempertanyakan, mempunyai, memulai, memungkinkan, menaiki, menambahkan, menandaskan, menanti, menanti-nanti, menantikan, menanya, menanyai, menanyakan, mendapat, mendapatkan, mendatang, mendatangi, mendatangkan, menegaskan, meng ...

# %%
from nltk.corpus import stopwords

STOPWORDS = set(stopwords.words('indonesian'))
def remove_stopwords(text):
    return " ".join([word for word in text.split() if word not in STOPWORDS])

# %%
df['temp_text'] = df['temp_text'].apply(lambda x: remove_stopwords(x))
df.head()
# Out:
#                 name  rating  \
# 0              Te Ir     4.0
# 1               RHDN     4.0
# 2       Mega Safitri     3.0
# 3  Muhammad Zidane A     5.0
# 4        Fahmi Amhar     4.0
#
#                                              snippet  \
# 0  Universitas yang menjadi bagian Pertamina (per...
# 1  Kampus nya cukup besar, lokasi pinggir jalan s...
# 2  Kami pilih kampus ini dg harapan setelah lulus...
# 3  walaupun terbilang masih baru, tetapi kampus i...
# 4  Campus ini memiliki sarana yang cukup lengkap,...
#
#                                            temp_text
# 0  universitas pertamina persero didukung tenaga ...
# 1  kampus nya lokasi pinggir jalan simprug byk fa...
# 2  pilih kampus harapan lulus tersalurkan pertami...
# 3  terbilang kampus akreditasi unggul masuk perin...
# 4  campus memiliki sarana lengkap dikelola mengha...

# %% [markdown]
# ## !!!Removal of Frequent Words

# %%
# Menghapus semua kata "nya" yang berdiri sendiri dalam kolom temp_text
df['temp_text'] = df['temp_text'].apply(lambda text: ' '.join([word for word in text.split() if word != 'nya']))

df.head()
# Out:
#                 name  rating  \
# 0              Te Ir     4.0
# 1               RHDN     4.0
# 2       Mega Safitri     3.0
# 3  Muhammad Zidane A     5.0
# 4        Fahmi Amhar     4.0
#
#                                              snippet  \
# 0  Universitas yang menjadi bagian Pertamina (per...
# 1  Kampus nya cukup besar, lokasi pinggir jalan s...
# 2  Kami pilih kampus ini dg harapan setelah lulus...
# 3  walaupun terbilang masih baru, tetapi kampus i...
# 4  Campus ini memiliki sarana yang cukup lengkap,...
#
#                                            temp_text
# 0  universitas pertamina persero didukung tenaga ...
# 1  kampus lokasi pinggir jalan simprug byk fasili...
# 2  pilih kampus harapan lulus tersalurkan pertami...
# 3  terbilang kampus akreditasi unggul masuk perin...
# 4  campus memiliki sarana lengkap dikelola mengha...

# %%
from collections import Counter
word_count = Counter()
for text in df['temp_text']:
    for word in text.split():
        word_count[word] += 1
        
word_count.most_common(10)
# Out:
# [('universitas', 47),
#  ('pertamina', 39),
#  ('kampus', 36),
#  ('bagus', 26),
#  ('good', 24),
#  ('semoga', 18),
#  ('fasilitas', 16),
#  ('gedung', 16),
#  ('kuliah', 16),
#  ('the', 15)]

# %%
df.head()
# Out:
#                 name  rating  \
# 0              Te Ir     4.0
# 1               RHDN     4.0
# 2       Mega Safitri     3.0
# 3  Muhammad Zidane A     5.0
# 4        Fahmi Amhar     4.0
#
#                                              snippet  \
# 0  Universitas yang menjadi bagian Pertamina (per...
# 1  Kampus nya cukup besar, lokasi pinggir jalan s...
# 2  Kami pilih kampus ini dg harapan setelah lulus...
# 3  walaupun terbilang masih baru, tetapi kampus i...
# 4  Campus ini memiliki sarana yang cukup lengkap,...
#
#                                            temp_text
# 0  universitas pertamina persero didukung tenaga ...
# 1  kampus lokasi pinggir jalan simprug byk fasili...
# 2  pilih kampus harapan lulus tersalurkan pertami...
# 3  terbilang kampus akreditasi unggul masuk perin...
# 4  campus memiliki sarana lengkap dikelola mengha...

# %%
# FREQUENT_WORDS = set(word for (word, wc) in word_count.most_common(3))
# def remove_freq_words(text):
#     return " ".join([word for word in text.split() if word not in FREQUENT_WORDS])

# %%
# df['temp_text'] = df['temp_text'].apply(lambda x: remove_freq_words(x))
# df.head()

# %% [markdown]
# ## Removal of Rare Words

# %%
# This cell should be moved after CELL INDEX 22
RARE_WORDS = set(word for (word, wc) in word_count.most_common()[:-10:-1])
print(RARE_WORDS)
# Out:
# {'pcu', 'mantułl', 'good😘👍🏻👍🏻👍🏻', 'calon', 'ml', 'ir', 'hi16', 'engineer', '😋'}

# %%
def remove_rare_words(text):
    return " ".join([word for word in text.split() if word not in RARE_WORDS])

# %%
df['temp_text'] = df['temp_text'].apply(lambda x: remove_rare_words(x))
df.head()
# Out:
#                 name  rating  \
# 0              Te Ir     4.0
# 1               RHDN     4.0
# 2       Mega Safitri     3.0
# 3  Muhammad Zidane A     5.0
# 4        Fahmi Amhar     4.0
#
#                                              snippet  \
# 0  Universitas yang menjadi bagian Pertamina (per...
# 1  Kampus nya cukup besar, lokasi pinggir jalan s...
# 2  Kami pilih kampus ini dg harapan setelah lulus...
# 3  walaupun terbilang masih baru, tetapi kampus i...
# 4  Campus ini memiliki sarana yang cukup lengkap,...
#
#                                            temp_text
# 0  universitas pertamina persero didukung tenaga ...
# 1  kampus lokasi pinggir jalan simprug byk fasili...
# 2  pilih kampus harapan lulus tersalurkan pertami...
# 3  terbilang kampus akreditasi unggul masuk perin...
# 4  campus memiliki sarana lengkap dikelola mengha...

# %% [markdown]
# ## Removal of Special characters

# %%
import re
def remove_spl_chars(text):
    text = re.sub('[^a-zA-Z0-9]', ' ', text)
    text = re.sub('\s+', ' ', text)
    return text
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\s'
# <>:4: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\hp\AppData\Local\Temp\ipykernel_16812\688201358.py:4: SyntaxWarning: invalid escape sequence '\s'
#   text = re.sub('\s+', ' ', text)

# %%
df['temp_text'] = df['temp_text'].apply(lambda x: remove_spl_chars(x))
df.head()
# Out:
#                 name  rating  \
# 0              Te Ir     4.0
# 1               RHDN     4.0
# 2       Mega Safitri     3.0
# 3  Muhammad Zidane A     5.0
# 4        Fahmi Amhar     4.0
#
#                                              snippet  \
# 0  Universitas yang menjadi bagian Pertamina (per...
# 1  Kampus nya cukup besar, lokasi pinggir jalan s...
# 2  Kami pilih kampus ini dg harapan setelah lulus...
# 3  walaupun terbilang masih baru, tetapi kampus i...
# 4  Campus ini memiliki sarana yang cukup lengkap,...
#
#                                            temp_text
# 0  universitas pertamina persero didukung tenaga ...
# 1  kampus lokasi pinggir jalan simprug byk fasili...
# 2  pilih kampus harapan lulus tersalurkan pertami...
# 3  terbilang kampus akreditasi unggul masuk perin...
# 4  campus memiliki sarana lengkap dikelola mengha...

# %% [markdown]
# ## Stemming

# %%
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory

# Membuat stemmer bahasa Indonesia
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# Fungsi stemming
def stem_words(text):
    return stemmer.stem(text)

# %%
# Menerapkan stemming pada kolom temp_text
df['stemmed_text'] = df['temp_text'].apply(lambda x: stem_words(x))
df.head()
# Out:
#                 name  rating  \
# 0              Te Ir     4.0
# 1               RHDN     4.0
# 2       Mega Safitri     3.0
# 3  Muhammad Zidane A     5.0
# 4        Fahmi Amhar     4.0
#
#                                              snippet  \
# 0  Universitas yang menjadi bagian Pertamina (per...
# 1  Kampus nya cukup besar, lokasi pinggir jalan s...
# 2  Kami pilih kampus ini dg harapan setelah lulus...
# 3  walaupun terbilang masih baru, tetapi kampus i...
# 4  Campus ini memiliki sarana yang cukup lengkap,...
#
#                                            temp_text  \
# 0  universitas pertamina persero didukung tenaga ...
# 1  kampus lokasi pinggir jalan simprug byk fasili...
# 2  pilih kampus harapan lulus tersalurkan pertami...
# 3  terbilang kampus akreditasi unggul masuk perin...
# 4  campus memiliki sarana lengkap dikelola mengha...
#
#                                         stemmed_text
# 0  universitas pertamina persero dukung tenaga aj...
# 1  kampus lokasi pinggir jalan simprug byk fasili...
# 2  pilih kampus harap lulus salur pertaminasejeni...
# 3  bilang kampus akreditasi unggul masuk peringka...
# 4  campus milik sarana lengkap kelola hasil mahas...

# %% [markdown]
# ## Lemmatization & POS Tagging

# %%
from nltk import pos_tag
from nltk.corpus import wordnet
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()
wordnet_map = {"N":wordnet.NOUN, "V": wordnet.VERB, "J": wordnet.ADJ, "R": wordnet.ADV}

def lemmatize_words(text):
    # find pos tags
    pos_text = pos_tag(text.split())
    return " ".join([lemmatizer.lemmatize(word, wordnet_map.get(pos[0], wordnet.NOUN)) for word, pos in pos_text])

# %%
from nltk.corpus import wordnet

wordnet.NOUN
# Out:
# 'n'

# %%
# import nltk
# nltk.download('averaged_perceptron_tagger')

# df['lemmatized_text'] = df['temp_text'].apply(lambda x: lemmatize_words(x))
# df.head()

# %%
df.sample(frac=1).head(10)
# Out:
#                        name  rating  \
# 240  Muhammad Rizky Hafizha     5.0
# 26       Zuliani Dalimunthe     4.0
# 10       Adi Noor Fajarudin     5.0
# 224          ALFADI SUDARMA     5.0
# 196           Zefania Tampi     4.0
# 178           Irsyad Hawari     5.0
# 86              Ryono Agung     3.0
# 179         Tedy Hermawan35     4.0
# 207            Raka Firdaus     5.0
# 7                     Nanda     5.0
#
#                                                snippet  \
# 240                                         Maba HI'16
# 26   Jalan menuju lokasi macet banget. Dari Depok b...
# 10   Mantap,, Kampus Teknologi dan Bisnis Energi Un...
# 224                                 Petroleum Engineer
# 196    Overall, it has comfortable atmosphere to study
# 178                                     Kampus amazing
# 86   sayangnya akses agak muter klo dari permata hi...
# 179                                              Tutup
# 207             Soon will be 500 World Best University
# 7    Kampus yang bagus, fasilitas 90% lengkap, deka...
#
#                                              temp_text  \
# 240                                               maba
# 26   jalan lokasi macet banget depok better kereta ...
# 10      mantap kampus teknologi bisnis energi unggulan
# 224                                          petroleum
# 196     overall it has comfortable atmosphere to study
# 178                                     kampus amazing
# 86             sayangnya akses muter klo permata hijau
# 179                                              tutup
# 207             soon will be 500 world best university
# 7    kampus bagus fasilitas 90 lengkap jalan raya t...
#
#                                           stemmed_text
# 240                                               maba
# 26   jalan lokasi macet banget depok better kereta ...
# 10        mantap kampus teknologi bisnis energi unggul
# 224                                          petroleum
# 196     overall it has comfortable atmosphere to study
# 178                                     kampus amazing
# 86                sayang akses muter klo permata hijau
# 179                                              tutup
# 207             soon will be 500 world best university
# 7    kampus bagus fasilitas 90 lengkap jalan raya t...

# %% [markdown]
# ## Tokenization

# %%
df.head()
# Out:
#                 name  rating  \
# 0              Te Ir     4.0
# 1               RHDN     4.0
# 2       Mega Safitri     3.0
# 3  Muhammad Zidane A     5.0
# 4        Fahmi Amhar     4.0
#
#                                              snippet  \
# 0  Universitas yang menjadi bagian Pertamina (per...
# 1  Kampus nya cukup besar, lokasi pinggir jalan s...
# 2  Kami pilih kampus ini dg harapan setelah lulus...
# 3  walaupun terbilang masih baru, tetapi kampus i...
# 4  Campus ini memiliki sarana yang cukup lengkap,...
#
#                                            temp_text  \
# 0  universitas pertamina persero didukung tenaga ...
# 1  kampus lokasi pinggir jalan simprug byk fasili...
# 2  pilih kampus harapan lulus tersalurkan pertami...
# 3  terbilang kampus akreditasi unggul masuk perin...
# 4  campus memiliki sarana lengkap dikelola mengha...
#
#                                         stemmed_text
# 0  universitas pertamina persero dukung tenaga aj...
# 1  kampus lokasi pinggir jalan simprug byk fasili...
# 2  pilih kampus harap lulus salur pertaminasejeni...
# 3  bilang kampus akreditasi unggul masuk peringka...
# 4  campus milik sarana lengkap kelola hasil mahas...

# %%
df.isnull().sum()
# Out:
# name            0
# rating          0
# snippet         0
# temp_text       0
# stemmed_text    0
# dtype: int64

# %%
from nltk.tokenize import word_tokenize

# Tokenisasi
df['tokenized_text'] = df['stemmed_text'].apply(lambda x: word_tokenize(x))
df.head()
# Out:
#                 name  rating  \
# 0              Te Ir     4.0
# 1               RHDN     4.0
# 2       Mega Safitri     3.0
# 3  Muhammad Zidane A     5.0
# 4        Fahmi Amhar     4.0
#
#                                              snippet  \
# 0  Universitas yang menjadi bagian Pertamina (per...
# 1  Kampus nya cukup besar, lokasi pinggir jalan s...
# 2  Kami pilih kampus ini dg harapan setelah lulus...
# 3  walaupun terbilang masih baru, tetapi kampus i...
# 4  Campus ini memiliki sarana yang cukup lengkap,...
#
#                                            temp_text  \
# 0  universitas pertamina persero didukung tenaga ...
# 1  kampus lokasi pinggir jalan simprug byk fasili...
# 2  pilih kampus harapan lulus tersalurkan pertami...
# 3  terbilang kampus akreditasi unggul masuk perin...
# 4  campus memiliki sarana lengkap dikelola mengha...
#
#                                         stemmed_text  \
# 0  universitas pertamina persero dukung tenaga aj...
# 1  kampus lokasi pinggir jalan simprug byk fasili...
# 2  pilih kampus harap lulus salur pertaminasejeni...
# 3  bilang kampus akreditasi unggul masuk peringka...
# 4  campus milik sarana lengkap kelola hasil mahas...
#
#                                       tokenized_text
# 0  [universitas, pertamina, persero, dukung, tena...
# 1  [kampus, lokasi, pinggir, jalan, simprug, byk,...
# 2  [pilih, kampus, harap, lulus, salur, pertamina...
# 3  [bilang, kampus, akreditasi, unggul, masuk, pe...
# 4  [campus, milik, sarana, lengkap, kelola, hasil...

# %%
# Cleaned text
df['cleaned_text'] = df['tokenized_text']
df.head()
# Out:
#                 name  rating  \
# 0              Te Ir     4.0
# 1               RHDN     4.0
# 2       Mega Safitri     3.0
# 3  Muhammad Zidane A     5.0
# 4        Fahmi Amhar     4.0
#
#                                              snippet  \
# 0  Universitas yang menjadi bagian Pertamina (per...
# 1  Kampus nya cukup besar, lokasi pinggir jalan s...
# 2  Kami pilih kampus ini dg harapan setelah lulus...
# 3  walaupun terbilang masih baru, tetapi kampus i...
# 4  Campus ini memiliki sarana yang cukup lengkap,...
#
#                                            temp_text  \
# 0  universitas pertamina persero didukung tenaga ...
# 1  kampus lokasi pinggir jalan simprug byk fasili...
# 2  pilih kampus harapan lulus tersalurkan pertami...
# 3  terbilang kampus akreditasi unggul masuk perin...
# 4  campus memiliki sarana lengkap dikelola mengha...
#
#                                         stemmed_text  \
# 0  universitas pertamina persero dukung tenaga aj...
# 1  kampus lokasi pinggir jalan simprug byk fasili...
# 2  pilih kampus harap lulus salur pertaminasejeni...
# 3  bilang kampus akreditasi unggul masuk peringka...
# 4  campus milik sarana lengkap kelola hasil mahas...
#
#                                       tokenized_text  \
# 0  [universitas, pertamina, persero, dukung, tena...
# 1  [kampus, lokasi, pinggir, jalan, simprug, byk,...
# 2  [pilih, kampus, harap, lulus, salur, pertamina...
# 3  [bilang, kampus, akreditasi, unggul, masuk, pe...
# 4  [campus, milik, sarana, lengkap, kelola, hasil...
#
#                                         cleaned_text
# 0  [universitas, pertamina, persero, dukung, tena...
# 1  [kampus, lokasi, pinggir, jalan, simprug, byk,...
# 2  [pilih, kampus, harap, lulus, salur, pertamina...
# 3  [bilang, kampus, akreditasi, unggul, masuk, pe...
# 4  [campus, milik, sarana, lengkap, kelola, hasil...

# %%
import os

try:
	# Save the dataframe to a CSV file
	df.to_csv(output_path, index=False)
	print(f"DataFrame successfully saved to {output_path}")
except Exception as e:
	print(f"An error occurred: {e}")
# Out:
# DataFrame successfully saved to ../../dataset/cleaned-data/UPer_Reviews_cleaned.csv
