# %% [markdown]
# # **Preprocessing | Telkom University (Bandung)**

# %% [markdown]
# # Text Preprocessing (Clean Data)

# %%
import pandas as pd
import string
import re
df = pd.read_csv('../../dataset/TelU_reviews.csv')

output_path = '../../dataset/cleaned-data/TelU_Reviews_cleaned.csv'

df.head()
# Out:
#    page             name                                               link  \
# 0     1    Daryl Cokelat  https://www.google.com/maps/contrib/1138191723...
# 1     1  Aries Indanarto  https://www.google.com/maps/contrib/1140064560...
# 2     1          mfft_27  https://www.google.com/maps/contrib/1171607731...
# 3     1  Fadhil Muhammad  https://www.google.com/maps/contrib/1038668775...
# 4     1  Rachmat Hidayar  https://www.google.com/maps/contrib/1001440503...
#
#                                            thumbnail  rating           date  \
# 0  https://lh3.googleusercontent.com/a-/ALV-UjXVE...     4.0   5 bulan lalu
# 1  https://lh3.googleusercontent.com/a/ACg8ocL-bK...     1.0  4 minggu lalu
# 2  https://lh3.googleusercontent.com/a-/ALV-UjVIK...     5.0  3 minggu lalu
# 3  https://lh3.googleusercontent.com/a-/ALV-UjWsF...     5.0   6 bulan lalu
# 4  https://lh3.googleusercontent.com/a-/ALV-UjVWC...     1.0  3 minggu lalu
#
#                                              snippet  \
# 0  Kampus swasta  di area yg padat, luas sekali t...
# 1  Siang hari ini hadir wisuda anak. Tempat wisud...
# 2        jangan lupa follow  Ig : mfft_27\ntrmksh 🙏🤩
# 3  Kampus swasta ternama, lokasi di bojongsoang k...
# 4  Yang terhormat bapak kepala satpam dan manajem...
#
#                                               images local_guide
# 0  ['https://lh5.googleusercontent.com/p/AF1QipMg...        True
# 1  ['https://lh5.googleusercontent.com/p/AF1QipPt...        True
# 2  ['https://lh5.googleusercontent.com/p/AF1QipNP...        True
# 3  ['https://lh5.googleusercontent.com/p/AF1QipMp...        True
# 4                                                NaN        True

# %%
# drop the columns
df = df.drop(columns=['page', 'link', 'thumbnail', 'date', 'images', 'local_guide'], axis=1)
df.head()
# Out:
#               name  rating                                            snippet
# 0    Daryl Cokelat     4.0  Kampus swasta  di area yg padat, luas sekali t...
# 1  Aries Indanarto     1.0  Siang hari ini hadir wisuda anak. Tempat wisud...
# 2          mfft_27     5.0        jangan lupa follow  Ig : mfft_27\ntrmksh 🙏🤩
# 3  Fadhil Muhammad     5.0  Kampus swasta ternama, lokasi di bojongsoang k...
# 4  Rachmat Hidayar     1.0  Yang terhormat bapak kepala satpam dan manajem...

# %% [markdown]
# ## Convert to lowercase

# %%
df['temp_text'] = df['snippet'].str.lower()
df.head()
# Out:
#               name  rating                                            snippet  \
# 0    Daryl Cokelat     4.0  Kampus swasta  di area yg padat, luas sekali t...
# 1  Aries Indanarto     1.0  Siang hari ini hadir wisuda anak. Tempat wisud...
# 2          mfft_27     5.0        jangan lupa follow  Ig : mfft_27\ntrmksh 🙏🤩
# 3  Fadhil Muhammad     5.0  Kampus swasta ternama, lokasi di bojongsoang k...
# 4  Rachmat Hidayar     1.0  Yang terhormat bapak kepala satpam dan manajem...
#
#                                            temp_text
# 0  kampus swasta  di area yg padat, luas sekali t...
# 1  siang hari ini hadir wisuda anak. tempat wisud...
# 2        jangan lupa follow  ig : mfft_27\ntrmksh 🙏🤩
# 3  kampus swasta ternama, lokasi di bojongsoang k...
# 4  yang terhormat bapak kepala satpam dan manajem...

# %% [markdown]
# ## Remove Missings Values

# %%
df.isnull().sum()
# Out:
# name          0
# rating        0
# snippet      28
# temp_text    28
# dtype: int64

# %%
df = df.dropna(subset=['temp_text'])
df.head()
# Out:
#               name  rating                                            snippet  \
# 0    Daryl Cokelat     4.0  Kampus swasta  di area yg padat, luas sekali t...
# 1  Aries Indanarto     1.0  Siang hari ini hadir wisuda anak. Tempat wisud...
# 2          mfft_27     5.0        jangan lupa follow  Ig : mfft_27\ntrmksh 🙏🤩
# 3  Fadhil Muhammad     5.0  Kampus swasta ternama, lokasi di bojongsoang k...
# 4  Rachmat Hidayar     1.0  Yang terhormat bapak kepala satpam dan manajem...
#
#                                            temp_text
# 0  kampus swasta  di area yg padat, luas sekali t...
# 1  siang hari ini hadir wisuda anak. tempat wisud...
# 2        jangan lupa follow  ig : mfft_27\ntrmksh 🙏🤩
# 3  kampus swasta ternama, lokasi di bojongsoang k...
# 4  yang terhormat bapak kepala satpam dan manajem...

# %%
df.isnull().sum()
# Out:
# name         0
# rating       0
# snippet      0
# temp_text    0
# dtype: int64

# %% [markdown]
# ## Menghapus Whitespace

# %%
def remove_extra_whitespace(text):
    # Menghapus spasi di awal dan akhir teks
    text = text.strip()
    # Menghapus spasi berlebih di tengah teks
    text = re.sub('\s+', ' ', text)
    return text

# Menerapkan fungsi pada kolom 'temp_text'
df['temp_text'] = df['temp_text'].apply(lambda x: remove_extra_whitespace(x))
df.head()
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\s'
# <>:5: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\hp\AppData\Local\Temp\ipykernel_6052\400237288.py:5: SyntaxWarning: invalid escape sequence '\s'
#   text = re.sub('\s+', ' ', text)
#               name  rating                                            snippet  \
# 0    Daryl Cokelat     4.0  Kampus swasta  di area yg padat, luas sekali t...
# 1  Aries Indanarto     1.0  Siang hari ini hadir wisuda anak. Tempat wisud...
# 2          mfft_27     5.0        jangan lupa follow  Ig : mfft_27\ntrmksh 🙏🤩
# 3  Fadhil Muhammad     5.0  Kampus swasta ternama, lokasi di bojongsoang k...
# 4  Rachmat Hidayar     1.0  Yang terhormat bapak kepala satpam dan manajem...
#
#                                            temp_text
# 0  kampus swasta di area yg padat, luas sekali tp...
# 1  siang hari ini hadir wisuda anak. tempat wisud...
# 2          jangan lupa follow ig : mfft_27 trmksh 🙏🤩
# 3  kampus swasta ternama, lokasi di bojongsoang k...
# 4  yang terhormat bapak kepala satpam dan manajem...

# %% [markdown]
# ## Removal of Punctuations

# %%
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
def remove_punctuations(text):
    punctuations = string.punctuation
    return text.translate(str.maketrans('', '', punctuations))

# %%
df['temp_text'] = df['temp_text'].apply(lambda x: remove_punctuations(x))
df.head()
# Out:
#               name  rating                                            snippet  \
# 0    Daryl Cokelat     4.0  Kampus swasta  di area yg padat, luas sekali t...
# 1  Aries Indanarto     1.0  Siang hari ini hadir wisuda anak. Tempat wisud...
# 2          mfft_27     5.0        jangan lupa follow  Ig : mfft_27\ntrmksh 🙏🤩
# 3  Fadhil Muhammad     5.0  Kampus swasta ternama, lokasi di bojongsoang k...
# 4  Rachmat Hidayar     1.0  Yang terhormat bapak kepala satpam dan manajem...
#
#                                            temp_text
# 0  kampus swasta di area yg padat luas sekali tp ...
# 1  siang hari ini hadir wisuda anak tempat wisuda...
# 2            jangan lupa follow ig  mfft27 trmksh 🙏🤩
# 3  kampus swasta ternama lokasi di bojongsoang ka...
# 4  yang terhormat bapak kepala satpam dan manajem...

# %% [markdown]
# ## Normalisasi Teks

# %%
# Kamus slang dan kata yang sudah dinormalisasi
slang_dict = {
    "gak": "tidak",
    "u": "you",
    "yg": "yang",
    "kalo": "kalau",
    "aja": "saja",
    "tdk": "tidak",
    "bgt": "banget",
    "dgn": "dengan",
    "dr": "dari",
    "dlm": "dalam",
    "sbg": "sebagai",
    "spt": "seperti",
    "utk": "untuk",
    "krn": "karena",
    "tp": "tapi",
    "jd": "jadi",
    "sy": "saya",
    "dg": "dengan",
    "trs": "terus",
    "sm": "sama",
    "pd": "pada",
    "blm": "belum",
    "sdh": "sudah",
    "td": "tadi",
    "lg": "lagi",
    "gmn": "gimana",
    "knp": "kenapa",
    "dpt": "dapat",
    "bbrp": "beberapa",
    "dl": "dulu",
    "kl": "kalau",
    "tmn": "teman",
    "msh": "masih",
    "syg": "sayang",
    "cm": "cuma",
    "bs": "bisa",
    "jg": "juga",
    "org": "orang",
    "bkn": "bukan",
    "bbrp": "beberapa",
    "dpt": "dapat",
    "dgn": "dengan",
    "dr": "dari",
    "gmn": "gimana",
    "hrs": "harus",
    "jgn": "jangan",
    "krn": "karena",
    "lg": "lagi",
    "pd": "pada",
    "sdh": "sudah",
    "sm": "sama",
    "tdk": "tidak",
    "tp": "tapi",
    "utk": "untuk",
    "yg": "yang"
}

# Fungsi untuk mengganti kata slang dengan kata yang sudah dinormalisasi
def normalize_text(text):
    words = text.split()
    normalized_words = [slang_dict.get(word, word) for word in words]
    return " ".join(normalized_words)

# Menerapkan normalisasi pada kolom temp_text
df['temp_text'] = df['temp_text'].apply(lambda x: normalize_text(x))
df.head(10)
# Out:
#                                 name  rating  \
# 0                      Daryl Cokelat     4.0
# 1                    Aries Indanarto     1.0
# 2                            mfft_27     5.0
# 3                    Fadhil Muhammad     5.0
# 4                    Rachmat Hidayar     1.0
# 5  Gelar Tanaya Risno Okta Pamungkas     3.0
# 6                       Yuhardin SSI     5.0
# 7                       Yadi setiadi     1.0
# 8             Muhammad Iqbal Winahyu     1.0
# 9                           Betha AF     5.0
#
#                                              snippet  \
# 0  Kampus swasta  di area yg padat, luas sekali t...
# 1  Siang hari ini hadir wisuda anak. Tempat wisud...
# 2        jangan lupa follow  Ig : mfft_27\ntrmksh 🙏🤩
# 3  Kampus swasta ternama, lokasi di bojongsoang k...
# 4  Yang terhormat bapak kepala satpam dan manajem...
# 5  Securitynya disana engga ramah ya, terus pada ...
# 6  2016, Bisa Bikin Brand, Terimakasih Ilmunya Pa...
# 7  ATURA  SIH ATURAN MASA DRIVER ONLINE OJOL MASU...
# 8  WASTE TIME BANGET DI SURUH JALAN KE ASRAMA PUT...
# 9     Kampus swasta terbaik di Indonesia. Kereeen...
#
#                                            temp_text
# 0  kampus swasta di area yang padat luas sekali t...
# 1  siang hari ini hadir wisuda anak tempat wisuda...
# 2             jangan lupa follow ig mfft27 trmksh 🙏🤩
# 3  kampus swasta ternama lokasi di bojongsoang ka...
# 4  yang terhormat bapak kepala satpam dan manajem...
# 5  securitynya disana engga ramah ya terus pada s...
# 6   2016 bisa bikin brand terimakasih ilmunya pak bi
# 7  atura sih aturan masa driver online ojol masuk...
# 8  waste time banget di suruh jalan ke asrama put...
# 9         kampus swasta terbaik di indonesia kereeen

# %% [markdown]
# ## Removal of Stopwords

# %%
from nltk.corpus import stopwords
", ".join(stopwords.words('indonesian'))
# Out:
# 'ada, adalah, adanya, adapun, agak, agaknya, agar, akan, akankah, akhir, akhiri, akhirnya, aku, akulah, amat, amatlah, anda, andalah, antar, antara, antaranya, apa, apaan, apabila, apakah, apalagi, apatah, artinya, asal, asalkan, atas, atau, ataukah, ataupun, awal, awalnya, bagai, bagaikan, bagaimana, bagaimanakah, bagaimanapun, bagi, bagian, bahkan, bahwa, bahwasanya, baik, bakal, bakalan, balik, banyak, bapak, baru, bawah, beberapa, begini, beginian, beginikah, beginilah, begitu, begitukah, begitulah, begitupun, bekerja, belakang, belakangan, belum, belumlah, benar, benarkah, benarlah, berada, berakhir, berakhirlah, berakhirnya, berapa, berapakah, berapalah, berapapun, berarti, berawal, berbagai, berdatangan, beri, berikan, berikut, berikutnya, berjumlah, berkali-kali, berkata, berkehendak, berkeinginan, berkenaan, berlainan, berlalu, berlangsung, berlebihan, bermacam, bermacam-macam, bermaksud, bermula, bersama, bersama-sama, bersiap, bersiap-siap, bertanya, bertanya-tanya, berturut, berturut-turut, bertutur, berujar, berupa, besar, betul, betulkah, biasa, biasanya, bila, bilakah, bisa, bisakah, boleh, bolehkah, bolehlah, buat, bukan, bukankah, bukanlah, bukannya, bulan, bung, cara, caranya, cukup, cukupkah, cukuplah, cuma, dahulu, dalam, dan, dapat, dari, daripada, datang, dekat, demi, demikian, demikianlah, dengan, depan, di, dia, diakhiri, diakhirinya, dialah, diantara, diantaranya, diberi, diberikan, diberikannya, dibuat, dibuatnya, didapat, didatangkan, digunakan, diibaratkan, diibaratkannya, diingat, diingatkan, diinginkan, dijawab, dijelaskan, dijelaskannya, dikarenakan, dikatakan, dikatakannya, dikerjakan, diketahui, diketahuinya, dikira, dilakukan, dilalui, dilihat, dimaksud, dimaksudkan, dimaksudkannya, dimaksudnya, diminta, dimintai, dimisalkan, dimulai, dimulailah, dimulainya, dimungkinkan, dini, dipastikan, diperbuat, diperbuatnya, dipergunakan, diperkirakan, diperlihatkan, diperlukan, diperlukannya, dipersoalkan, dipertanyakan, dipunyai, diri, dirinya, disampaikan, disebut, disebutkan, disebutkannya, disini, disinilah, ditambahkan, ditandaskan, ditanya, ditanyai, ditanyakan, ditegaskan, ditujukan, ditunjuk, ditunjuki, ditunjukkan, ditunjukkannya, ditunjuknya, dituturkan, dituturkannya, diucapkan, diucapkannya, diungkapkan, dong, dua, dulu, empat, enggak, enggaknya, entah, entahlah, guna, gunakan, hal, hampir, hanya, hanyalah, hari, harus, haruslah, harusnya, hendak, hendaklah, hendaknya, hingga, ia, ialah, ibarat, ibaratkan, ibaratnya, ibu, ikut, ingat, ingat-ingat, ingin, inginkah, inginkan, ini, inikah, inilah, itu, itukah, itulah, jadi, jadilah, jadinya, jangan, jangankan, janganlah, jauh, jawab, jawaban, jawabnya, jelas, jelaskan, jelaslah, jelasnya, jika, jikalau, juga, jumlah, jumlahnya, justru, kala, kalau, kalaulah, kalaupun, kalian, kami, kamilah, kamu, kamulah, kan, kapan, kapankah, kapanpun, karena, karenanya, kasus, kata, katakan, katakanlah, katanya, ke, keadaan, kebetulan, kecil, kedua, keduanya, keinginan, kelamaan, kelihatan, kelihatannya, kelima, keluar, kembali, kemudian, kemungkinan, kemungkinannya, kenapa, kepada, kepadanya, kesampaian, keseluruhan, keseluruhannya, keterlaluan, ketika, khususnya, kini, kinilah, kira, kira-kira, kiranya, kita, kitalah, kok, kurang, lagi, lagian, lah, lain, lainnya, lalu, lama, lamanya, lanjut, lanjutnya, lebih, lewat, lima, luar, macam, maka, makanya, makin, malah, malahan, mampu, mampukah, mana, manakala, manalagi, masa, masalah, masalahnya, masih, masihkah, masing, masing-masing, mau, maupun, melainkan, melakukan, melalui, melihat, melihatnya, memang, memastikan, memberi, memberikan, membuat, memerlukan, memihak, meminta, memintakan, memisalkan, memperbuat, mempergunakan, memperkirakan, memperlihatkan, mempersiapkan, mempersoalkan, mempertanyakan, mempunyai, memulai, memungkinkan, menaiki, menambahkan, menandaskan, menanti, menanti-nanti, menantikan, menanya, menanyai, menanyakan, mendapat, mendapatkan, mendatang, mendatangi, mendatangkan, menegaskan, meng ...

# %%
from nltk.corpus import stopwords

STOPWORDS = set(stopwords.words('indonesian'))
def remove_stopwords(text):
    return " ".join([word for word in text.split() if word not in STOPWORDS])

# %%
df['temp_text'] = df['temp_text'].apply(lambda x: remove_stopwords(x))
df.head()
# Out:
#               name  rating                                            snippet  \
# 0    Daryl Cokelat     4.0  Kampus swasta  di area yg padat, luas sekali t...
# 1  Aries Indanarto     1.0  Siang hari ini hadir wisuda anak. Tempat wisud...
# 2          mfft_27     5.0        jangan lupa follow  Ig : mfft_27\ntrmksh 🙏🤩
# 3  Fadhil Muhammad     5.0  Kampus swasta ternama, lokasi di bojongsoang k...
# 4  Rachmat Hidayar     1.0  Yang terhormat bapak kepala satpam dan manajem...
#
#                                            temp_text
# 0  kampus swasta area padat luas sayang penataan ...
# 1  siang hadir wisuda anak wisuda worted duduknya...
# 2                    lupa follow ig mfft27 trmksh 🙏🤩
# 3  kampus swasta ternama lokasi bojongsoang kabup...
# 4  terhormat kepala satpam manajemen telkom dimoh...

# %% [markdown]
# ## !!!Removal of Frequent Words

# %%
# Menghapus semua kata "nya" yang berdiri sendiri dalam kolom temp_text
df['temp_text'] = df['temp_text'].apply(lambda text: ' '.join([word for word in text.split() if word != 'nya']))

df.head()
# Out:
#               name  rating                                            snippet  \
# 0    Daryl Cokelat     4.0  Kampus swasta  di area yg padat, luas sekali t...
# 1  Aries Indanarto     1.0  Siang hari ini hadir wisuda anak. Tempat wisud...
# 2          mfft_27     5.0        jangan lupa follow  Ig : mfft_27\ntrmksh 🙏🤩
# 3  Fadhil Muhammad     5.0  Kampus swasta ternama, lokasi di bojongsoang k...
# 4  Rachmat Hidayar     1.0  Yang terhormat bapak kepala satpam dan manajem...
#
#                                            temp_text
# 0  kampus swasta area padat luas sayang penataan ...
# 1  siang hadir wisuda anak wisuda worted duduknya...
# 2                    lupa follow ig mfft27 trmksh 🙏🤩
# 3  kampus swasta ternama lokasi bojongsoang kabup...
# 4  terhormat kepala satpam manajemen telkom dimoh...

# %%
from collections import Counter
word_count = Counter()
for text in df['temp_text']:
    for word in text.split():
        word_count[word] += 1
        
word_count.most_common(10)
# Out:
# [('kampus', 252),
#  ('telkom', 146),
#  ('bagus', 103),
#  ('university', 95),
#  ('luas', 93),
#  ('the', 90),
#  ('universitas', 85),
#  ('nyaman', 70),
#  ('jalan', 68),
#  ('kuliah', 62)]

# %%
df.head()
# Out:
#               name  rating                                            snippet  \
# 0    Daryl Cokelat     4.0  Kampus swasta  di area yg padat, luas sekali t...
# 1  Aries Indanarto     1.0  Siang hari ini hadir wisuda anak. Tempat wisud...
# 2          mfft_27     5.0        jangan lupa follow  Ig : mfft_27\ntrmksh 🙏🤩
# 3  Fadhil Muhammad     5.0  Kampus swasta ternama, lokasi di bojongsoang k...
# 4  Rachmat Hidayar     1.0  Yang terhormat bapak kepala satpam dan manajem...
#
#                                            temp_text
# 0  kampus swasta area padat luas sayang penataan ...
# 1  siang hadir wisuda anak wisuda worted duduknya...
# 2                    lupa follow ig mfft27 trmksh 🙏🤩
# 3  kampus swasta ternama lokasi bojongsoang kabup...
# 4  terhormat kepala satpam manajemen telkom dimoh...

# %%
# FREQUENT_WORDS = set(word for (word, wc) in word_count.most_common(3))
# def remove_freq_words(text):
#     return " ".join([word for word in text.split() if word not in FREQUENT_WORDS])

# %%
# df['temp_text'] = df['temp_text'].apply(lambda x: remove_freq_words(x))
# df.head()

# %% [markdown]
# ## Removal of Rare Words

# %%
# This cell should be moved after CELL INDEX 22
RARE_WORDS = set(word for (word, wc) in word_count.most_common()[:-10:-1])
print(RARE_WORDS)
# Out:
# {'like', 'bro', 'day', 'enjoy', 'toward', 'heaven', 'relax', 'coment', 'negry'}

# %%
def remove_rare_words(text):
    return " ".join([word for word in text.split() if word not in RARE_WORDS])

# %%
df['temp_text'] = df['temp_text'].apply(lambda x: remove_rare_words(x))
df.head()
# Out:
#               name  rating                                            snippet  \
# 0    Daryl Cokelat     4.0  Kampus swasta  di area yg padat, luas sekali t...
# 1  Aries Indanarto     1.0  Siang hari ini hadir wisuda anak. Tempat wisud...
# 2          mfft_27     5.0        jangan lupa follow  Ig : mfft_27\ntrmksh 🙏🤩
# 3  Fadhil Muhammad     5.0  Kampus swasta ternama, lokasi di bojongsoang k...
# 4  Rachmat Hidayar     1.0  Yang terhormat bapak kepala satpam dan manajem...
#
#                                            temp_text
# 0  kampus swasta area padat luas sayang penataan ...
# 1  siang hadir wisuda anak wisuda worted duduknya...
# 2                    lupa follow ig mfft27 trmksh 🙏🤩
# 3  kampus swasta ternama lokasi bojongsoang kabup...
# 4  terhormat kepala satpam manajemen telkom dimoh...

# %% [markdown]
# ## Removal of Special characters

# %%
import re
def remove_spl_chars(text):
    text = re.sub('[^a-zA-Z0-9]', ' ', text)
    text = re.sub('\s+', ' ', text)
    return text
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\s'
# <>:4: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\hp\AppData\Local\Temp\ipykernel_6052\688201358.py:4: SyntaxWarning: invalid escape sequence '\s'
#   text = re.sub('\s+', ' ', text)

# %%
df['temp_text'] = df['temp_text'].apply(lambda x: remove_spl_chars(x))
df.head()
# Out:
#               name  rating                                            snippet  \
# 0    Daryl Cokelat     4.0  Kampus swasta  di area yg padat, luas sekali t...
# 1  Aries Indanarto     1.0  Siang hari ini hadir wisuda anak. Tempat wisud...
# 2          mfft_27     5.0        jangan lupa follow  Ig : mfft_27\ntrmksh 🙏🤩
# 3  Fadhil Muhammad     5.0  Kampus swasta ternama, lokasi di bojongsoang k...
# 4  Rachmat Hidayar     1.0  Yang terhormat bapak kepala satpam dan manajem...
#
#                                            temp_text
# 0  kampus swasta area padat luas sayang penataan ...
# 1  siang hadir wisuda anak wisuda worted duduknya...
# 2                      lupa follow ig mfft27 trmksh
# 3  kampus swasta ternama lokasi bojongsoang kabup...
# 4  terhormat kepala satpam manajemen telkom dimoh...

# %% [markdown]
# ## Stemming

# %%
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory

# Membuat stemmer bahasa Indonesia
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# Fungsi stemming
def stem_words(text):
    return stemmer.stem(text)

# %%
# Menerapkan stemming pada kolom temp_text
df['stemmed_text'] = df['temp_text'].apply(lambda x: stem_words(x))
df.head()
# Out:
#               name  rating                                            snippet  \
# 0    Daryl Cokelat     4.0  Kampus swasta  di area yg padat, luas sekali t...
# 1  Aries Indanarto     1.0  Siang hari ini hadir wisuda anak. Tempat wisud...
# 2          mfft_27     5.0        jangan lupa follow  Ig : mfft_27\ntrmksh 🙏🤩
# 3  Fadhil Muhammad     5.0  Kampus swasta ternama, lokasi di bojongsoang k...
# 4  Rachmat Hidayar     1.0  Yang terhormat bapak kepala satpam dan manajem...
#
#                                            temp_text  \
# 0  kampus swasta area padat luas sayang penataan ...
# 1  siang hadir wisuda anak wisuda worted duduknya...
# 2                      lupa follow ig mfft27 trmksh
# 3  kampus swasta ternama lokasi bojongsoang kabup...
# 4  terhormat kepala satpam manajemen telkom dimoh...
#
#                                         stemmed_text
# 0  kampus swasta area padat luas sayang tata park...
# 1  siang hadir wisuda anak wisuda worted duduk se...
# 2                       lupa follow ig mfft27 trmksh
# 3  kampus swasta nama lokasi bojongsoang kabupate...
# 4  hormat kepala satpam manajemen telkom mohon at...

# %% [markdown]
# ## Lemmatization & POS Tagging

# %%
from nltk import pos_tag
from nltk.corpus import wordnet
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()
wordnet_map = {"N":wordnet.NOUN, "V": wordnet.VERB, "J": wordnet.ADJ, "R": wordnet.ADV}

def lemmatize_words(text):
    # find pos tags
    pos_text = pos_tag(text.split())
    return " ".join([lemmatizer.lemmatize(word, wordnet_map.get(pos[0], wordnet.NOUN)) for word, pos in pos_text])

# %%
from nltk.corpus import wordnet

wordnet.NOUN
# Out:
# 'n'

# %%
# import nltk
# nltk.download('averaged_perceptron_tagger')

# df['lemmatized_text'] = df['temp_text'].apply(lambda x: lemmatize_words(x))
# df.head()

# %%
df.sample(frac=1).head(10)
# Out:
#                             name  rating  \
# 672  Nabilla Syahvalensi Durasid     5.0
# 80                  Edi Kurniadi     5.0
# 758                   Ahmad Afif     4.0
# 675               Muhammad Rafif     5.0
# 78             Azzahra Dhanindya     5.0
# 430                    Pak Akmal     4.0
# 32                 Adetia Adetia     5.0
# 397                achmad ridwan     1.0
# 399              Arfan Nur Akbar     5.0
# 739                      SUYATNO     4.0
#
#                                                snippet  \
# 672                             kampus tercinta ~~~~♥♥
# 80     Kini tambah asri dan hijau banyak bangunan baru
# 758                                 Universitas swasta
# 675                      kampus world class university
# 78   Di stt adem banget, buat yang suka sama IT waj...
# 430        Mau info kpn msk asrama telkom utk mhs 2018
# 32   Setelah 2 tahun ga ke sini ternyata perubahann...
# 397                   Tempatnya kotor gak menyenangkan
# 399              minusnya panas sama suka banjir doang
# 739                                             Mantul
#
#                                              temp_text  \
# 672                                   kampus tercinta
# 80                                 asri hijau bangunan
# 758                                 universitas swasta
# 675                      kampus world class university
# 78             stt adem banget suka it wajib masuk nih
# 430                info kpn msk asrama telkom mhs 2018
# 32   2 ga perubahannya berasa vibes green campusnya...
# 397                       tempatnya kotor menyenangkan
# 399                   minusnya panas suka banjir doang
# 739                                             mantul
#
#                                           stemmed_text
# 672                                       kampus cinta
# 80                                   asri hijau bangun
# 758                                 universitas swasta
# 675                      kampus world class university
# 78             stt adem banget suka it wajib masuk nih
# 430                info kpn msk asrama telkom mhs 2018
# 32   2 ga ubah asa vibes green campusnya pohon rind...
# 397                                tempat kotor senang
# 399                      minus panas suka banjir doang
# 739                                             mantul

# %% [markdown]
# ## Tokenization

# %%
df.head()
# Out:
#               name  rating                                            snippet  \
# 0    Daryl Cokelat     4.0  Kampus swasta  di area yg padat, luas sekali t...
# 1  Aries Indanarto     1.0  Siang hari ini hadir wisuda anak. Tempat wisud...
# 2          mfft_27     5.0        jangan lupa follow  Ig : mfft_27\ntrmksh 🙏🤩
# 3  Fadhil Muhammad     5.0  Kampus swasta ternama, lokasi di bojongsoang k...
# 4  Rachmat Hidayar     1.0  Yang terhormat bapak kepala satpam dan manajem...
#
#                                            temp_text  \
# 0  kampus swasta area padat luas sayang penataan ...
# 1  siang hadir wisuda anak wisuda worted duduknya...
# 2                      lupa follow ig mfft27 trmksh
# 3  kampus swasta ternama lokasi bojongsoang kabup...
# 4  terhormat kepala satpam manajemen telkom dimoh...
#
#                                         stemmed_text
# 0  kampus swasta area padat luas sayang tata park...
# 1  siang hadir wisuda anak wisuda worted duduk se...
# 2                       lupa follow ig mfft27 trmksh
# 3  kampus swasta nama lokasi bojongsoang kabupate...
# 4  hormat kepala satpam manajemen telkom mohon at...

# %%
df.isnull().sum()
# Out:
# name            0
# rating          0
# snippet         0
# temp_text       0
# stemmed_text    0
# dtype: int64

# %%
from nltk.tokenize import word_tokenize

# Tokenisasi
df['tokenized_text'] = df['stemmed_text'].apply(lambda x: word_tokenize(x))
df.head()
# Out:
#               name  rating                                            snippet  \
# 0    Daryl Cokelat     4.0  Kampus swasta  di area yg padat, luas sekali t...
# 1  Aries Indanarto     1.0  Siang hari ini hadir wisuda anak. Tempat wisud...
# 2          mfft_27     5.0        jangan lupa follow  Ig : mfft_27\ntrmksh 🙏🤩
# 3  Fadhil Muhammad     5.0  Kampus swasta ternama, lokasi di bojongsoang k...
# 4  Rachmat Hidayar     1.0  Yang terhormat bapak kepala satpam dan manajem...
#
#                                            temp_text  \
# 0  kampus swasta area padat luas sayang penataan ...
# 1  siang hadir wisuda anak wisuda worted duduknya...
# 2                      lupa follow ig mfft27 trmksh
# 3  kampus swasta ternama lokasi bojongsoang kabup...
# 4  terhormat kepala satpam manajemen telkom dimoh...
#
#                                         stemmed_text  \
# 0  kampus swasta area padat luas sayang tata park...
# 1  siang hadir wisuda anak wisuda worted duduk se...
# 2                       lupa follow ig mfft27 trmksh
# 3  kampus swasta nama lokasi bojongsoang kabupate...
# 4  hormat kepala satpam manajemen telkom mohon at...
#
#                                       tokenized_text
# 0  [kampus, swasta, area, padat, luas, sayang, ta...
# 1  [siang, hadir, wisuda, anak, wisuda, worted, d...
# 2                 [lupa, follow, ig, mfft27, trmksh]
# 3  [kampus, swasta, nama, lokasi, bojongsoang, ka...
# 4  [hormat, kepala, satpam, manajemen, telkom, mo...

# %%
# Cleaned text
df['cleaned_text'] = df['tokenized_text']
df.head()
# Out:
#               name  rating                                            snippet  \
# 0    Daryl Cokelat     4.0  Kampus swasta  di area yg padat, luas sekali t...
# 1  Aries Indanarto     1.0  Siang hari ini hadir wisuda anak. Tempat wisud...
# 2          mfft_27     5.0        jangan lupa follow  Ig : mfft_27\ntrmksh 🙏🤩
# 3  Fadhil Muhammad     5.0  Kampus swasta ternama, lokasi di bojongsoang k...
# 4  Rachmat Hidayar     1.0  Yang terhormat bapak kepala satpam dan manajem...
#
#                                            temp_text  \
# 0  kampus swasta area padat luas sayang penataan ...
# 1  siang hadir wisuda anak wisuda worted duduknya...
# 2                      lupa follow ig mfft27 trmksh
# 3  kampus swasta ternama lokasi bojongsoang kabup...
# 4  terhormat kepala satpam manajemen telkom dimoh...
#
#                                         stemmed_text  \
# 0  kampus swasta area padat luas sayang tata park...
# 1  siang hadir wisuda anak wisuda worted duduk se...
# 2                       lupa follow ig mfft27 trmksh
# 3  kampus swasta nama lokasi bojongsoang kabupate...
# 4  hormat kepala satpam manajemen telkom mohon at...
#
#                                       tokenized_text  \
# 0  [kampus, swasta, area, padat, luas, sayang, ta...
# 1  [siang, hadir, wisuda, anak, wisuda, worted, d...
# 2                 [lupa, follow, ig, mfft27, trmksh]
# 3  [kampus, swasta, nama, lokasi, bojongsoang, ka...
# 4  [hormat, kepala, satpam, manajemen, telkom, mo...
#
#                                         cleaned_text
# 0  [kampus, swasta, area, padat, luas, sayang, ta...
# 1  [siang, hadir, wisuda, anak, wisuda, worted, d...
# 2                 [lupa, follow, ig, mfft27, trmksh]
# 3  [kampus, swasta, nama, lokasi, bojongsoang, ka...
# 4  [hormat, kepala, satpam, manajemen, telkom, mo...

# %%
import os

try:
	# Save the dataframe to a CSV file
	df.to_csv(output_path, index=False)
	print(f"DataFrame successfully saved to {output_path}")
except Exception as e:
	print(f"An error occurred: {e}")
# Out:
# DataFrame successfully saved to ../../dataset/cleaned-data/TelU_Reviews_cleaned.csv
