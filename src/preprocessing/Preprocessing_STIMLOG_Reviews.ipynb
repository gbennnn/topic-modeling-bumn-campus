# %% [markdown]
# # **Preprocessing | Sekolah Tinggi Manajemen Logistik Indonesia (STIMLOG)**

# %% [markdown]
# # Text Preprocessing (Clean Data)

# %%
import pandas as pd
import string
import re
df = pd.read_csv('../../dataset/STIMLOG_Reviews.csv')

output_path = '../../dataset/cleaned-data/STIMLOG_Reviews_cleaned.csv'

df.head()
# Out:
#    page                   name  \
# 0     1        Rian Syahariany
# 1     1  Ananda Hafizhah Putri
# 2     1       PRADYA PARAMITHA
# 3     1   Juli Amirah Nasution
# 4     1             Ayah Endah
#
#                                                 link  \
# 0  https://www.google.com/maps/contrib/1002537162...
# 1  https://www.google.com/maps/contrib/1184453129...
# 2  https://www.google.com/maps/contrib/1107620026...
# 3  https://www.google.com/maps/contrib/1151706215...
# 4  https://www.google.com/maps/contrib/1110976044...
#
#                                            thumbnail  rating          date  \
# 0  https://lh3.googleusercontent.com/a-/ALV-UjWws...     5.0  2 bulan lalu
# 1  https://lh3.googleusercontent.com/a-/ALV-UjWw_...     4.0  2 tahun lalu
# 2  https://lh3.googleusercontent.com/a/ACg8ocJFiR...     1.0  7 bulan lalu
# 3  https://lh3.googleusercontent.com/a-/ALV-UjVB0...     5.0  6 tahun lalu
# 4  https://lh3.googleusercontent.com/a-/ALV-UjXMt...     5.0  3 tahun lalu
#
#                                              snippet  \
# 0  Kampus kereen...dosennya sangat support lokasi...
# 1  Kampus yang nyaman. Suasana cukup heteorgen ka...
# 2  Ada salah satu dosen yg mempersulit mahasiswan...
# 3  Sekolah Tinggi pertama di Indonesia yang berko...
# 4  Kampus nya luas, bersih dan bagus. Udaranya se...
#
#                                               images local_guide
# 0                                                NaN        True
# 1  ['https://lh5.googleusercontent.com/p/AF1QipMO...        True
# 2                                                NaN         NaN
# 3  ['https://lh5.googleusercontent.com/p/AF1QipMO...        True
# 4  ['https://lh5.googleusercontent.com/p/AF1QipMR...        True

# %%
# drop the columns
df = df.drop(columns=['page', 'link', 'thumbnail', 'date', 'images', 'local_guide'], axis=1)
df.head()
# Out:
#                     name  rating  \
# 0        Rian Syahariany     5.0
# 1  Ananda Hafizhah Putri     4.0
# 2       PRADYA PARAMITHA     1.0
# 3   Juli Amirah Nasution     5.0
# 4             Ayah Endah     5.0
#
#                                              snippet
# 0  Kampus kereen...dosennya sangat support lokasi...
# 1  Kampus yang nyaman. Suasana cukup heteorgen ka...
# 2  Ada salah satu dosen yg mempersulit mahasiswan...
# 3  Sekolah Tinggi pertama di Indonesia yang berko...
# 4  Kampus nya luas, bersih dan bagus. Udaranya se...

# %% [markdown]
# ## Convert to lowercase

# %%
df['temp_text'] = df['snippet'].str.lower()
df.head()
# Out:
#                     name  rating  \
# 0        Rian Syahariany     5.0
# 1  Ananda Hafizhah Putri     4.0
# 2       PRADYA PARAMITHA     1.0
# 3   Juli Amirah Nasution     5.0
# 4             Ayah Endah     5.0
#
#                                              snippet  \
# 0  Kampus kereen...dosennya sangat support lokasi...
# 1  Kampus yang nyaman. Suasana cukup heteorgen ka...
# 2  Ada salah satu dosen yg mempersulit mahasiswan...
# 3  Sekolah Tinggi pertama di Indonesia yang berko...
# 4  Kampus nya luas, bersih dan bagus. Udaranya se...
#
#                                            temp_text
# 0  kampus kereen...dosennya sangat support lokasi...
# 1  kampus yang nyaman. suasana cukup heteorgen ka...
# 2  ada salah satu dosen yg mempersulit mahasiswan...
# 3  sekolah tinggi pertama di indonesia yang berko...
# 4  kampus nya luas, bersih dan bagus. udaranya se...

# %% [markdown]
# ## Remove Missings Values

# %%
df.isnull().sum()
# Out:
# name          0
# rating        0
# snippet      95
# temp_text    95
# dtype: int64

# %%
df = df.dropna(subset=['temp_text'])
df.head()
# Out:
#                     name  rating  \
# 0        Rian Syahariany     5.0
# 1  Ananda Hafizhah Putri     4.0
# 2       PRADYA PARAMITHA     1.0
# 3   Juli Amirah Nasution     5.0
# 4             Ayah Endah     5.0
#
#                                              snippet  \
# 0  Kampus kereen...dosennya sangat support lokasi...
# 1  Kampus yang nyaman. Suasana cukup heteorgen ka...
# 2  Ada salah satu dosen yg mempersulit mahasiswan...
# 3  Sekolah Tinggi pertama di Indonesia yang berko...
# 4  Kampus nya luas, bersih dan bagus. Udaranya se...
#
#                                            temp_text
# 0  kampus kereen...dosennya sangat support lokasi...
# 1  kampus yang nyaman. suasana cukup heteorgen ka...
# 2  ada salah satu dosen yg mempersulit mahasiswan...
# 3  sekolah tinggi pertama di indonesia yang berko...
# 4  kampus nya luas, bersih dan bagus. udaranya se...

# %%
df.isnull().sum()
# Out:
# name         0
# rating       0
# snippet      0
# temp_text    0
# dtype: int64

# %% [markdown]
# ## Menghapus Whitespace

# %%
def remove_extra_whitespace(text):
    # Menghapus spasi di awal dan akhir teks
    text = text.strip()
    # Menghapus spasi berlebih di tengah teks
    text = re.sub('\s+', ' ', text)
    return text

# Menerapkan fungsi pada kolom 'temp_text'
df['temp_text'] = df['temp_text'].apply(lambda x: remove_extra_whitespace(x))
df.head()
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\s'
# <>:5: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\hp\AppData\Local\Temp\ipykernel_27676\400237288.py:5: SyntaxWarning: invalid escape sequence '\s'
#   text = re.sub('\s+', ' ', text)
#                     name  rating  \
# 0        Rian Syahariany     5.0
# 1  Ananda Hafizhah Putri     4.0
# 2       PRADYA PARAMITHA     1.0
# 3   Juli Amirah Nasution     5.0
# 4             Ayah Endah     5.0
#
#                                              snippet  \
# 0  Kampus kereen...dosennya sangat support lokasi...
# 1  Kampus yang nyaman. Suasana cukup heteorgen ka...
# 2  Ada salah satu dosen yg mempersulit mahasiswan...
# 3  Sekolah Tinggi pertama di Indonesia yang berko...
# 4  Kampus nya luas, bersih dan bagus. Udaranya se...
#
#                                            temp_text
# 0  kampus kereen...dosennya sangat support lokasi...
# 1  kampus yang nyaman. suasana cukup heteorgen ka...
# 2  ada salah satu dosen yg mempersulit mahasiswan...
# 3  sekolah tinggi pertama di indonesia yang berko...
# 4  kampus nya luas, bersih dan bagus. udaranya se...

# %% [markdown]
# ## Removal of Punctuations

# %%
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
def remove_punctuations(text):
    punctuations = string.punctuation
    return text.translate(str.maketrans('', '', punctuations))

# %%
df['temp_text'] = df['temp_text'].apply(lambda x: remove_punctuations(x))
df.head()
# Out:
#                     name  rating  \
# 0        Rian Syahariany     5.0
# 1  Ananda Hafizhah Putri     4.0
# 2       PRADYA PARAMITHA     1.0
# 3   Juli Amirah Nasution     5.0
# 4             Ayah Endah     5.0
#
#                                              snippet  \
# 0  Kampus kereen...dosennya sangat support lokasi...
# 1  Kampus yang nyaman. Suasana cukup heteorgen ka...
# 2  Ada salah satu dosen yg mempersulit mahasiswan...
# 3  Sekolah Tinggi pertama di Indonesia yang berko...
# 4  Kampus nya luas, bersih dan bagus. Udaranya se...
#
#                                            temp_text
# 0  kampus kereendosennya sangat support lokasi te...
# 1  kampus yang nyaman suasana cukup heteorgen kar...
# 2  ada salah satu dosen yg mempersulit mahasiswan...
# 3  sekolah tinggi pertama di indonesia yang berko...
# 4    kampus nya luas bersih dan bagus udaranya sejuk

# %% [markdown]
# ## Normalisasi Teks

# %%
# Kamus slang dan kata yang sudah dinormalisasi
slang_dict = {
    "gak": "tidak",
    "u": "you",
    "yg": "yang",
    "kalo": "kalau",
    "aja": "saja",
    "tdk": "tidak",
    "bgt": "banget",
    "dgn": "dengan",
    "dr": "dari",
    "dlm": "dalam",
    "sbg": "sebagai",
    "spt": "seperti",
    "utk": "untuk",
    "krn": "karena",
    "tp": "tapi",
    "jd": "jadi",
    "sy": "saya",
    "dg": "dengan",
    "trs": "terus",
    "sm": "sama",
    "pd": "pada",
    "blm": "belum",
    "sdh": "sudah",
    "td": "tadi",
    "lg": "lagi",
    "gmn": "gimana",
    "knp": "kenapa",
    "dpt": "dapat",
    "bbrp": "beberapa",
    "dl": "dulu",
    "kl": "kalau",
    "tmn": "teman",
    "msh": "masih",
    "syg": "sayang",
    "cm": "cuma",
    "bs": "bisa",
    "jg": "juga",
    "org": "orang",
    "bkn": "bukan",
    "bbrp": "beberapa",
    "dpt": "dapat",
    "dgn": "dengan",
    "dr": "dari",
    "gmn": "gimana",
    "hrs": "harus",
    "jgn": "jangan",
    "krn": "karena",
    "lg": "lagi",
    "pd": "pada",
    "sdh": "sudah",
    "sm": "sama",
    "tdk": "tidak",
    "tp": "tapi",
    "utk": "untuk",
    "yg": "yang"
}

# Fungsi untuk mengganti kata slang dengan kata yang sudah dinormalisasi
def normalize_text(text):
    words = text.split()
    normalized_words = [slang_dict.get(word, word) for word in words]
    return " ".join(normalized_words)

# Menerapkan normalisasi pada kolom temp_text
df['temp_text'] = df['temp_text'].apply(lambda x: normalize_text(x))
df.head(10)
# Out:
#                                                 name  rating  \
# 0                                    Rian Syahariany     5.0
# 1                              Ananda Hafizhah Putri     4.0
# 2                                   PRADYA PARAMITHA     1.0
# 3                               Juli Amirah Nasution     5.0
# 4                                         Ayah Endah     5.0
# 5  KDKW CENTER KOTA MOJOKERTO (Wa jek pak moh yusri)     3.0
# 6                             Denis Erlangga Maulana     5.0
# 7                                            Rosid S     5.0
# 8                                       lina lusiana     5.0
# 9                                   M. J. S. Priatna     3.0
#
#                                              snippet  \
# 0  Kampus kereen...dosennya sangat support lokasi...
# 1  Kampus yang nyaman. Suasana cukup heteorgen ka...
# 2  Ada salah satu dosen yg mempersulit mahasiswan...
# 3  Sekolah Tinggi pertama di Indonesia yang berko...
# 4  Kampus nya luas, bersih dan bagus. Udaranya se...
# 5  Sepi kuliah belum berjalan secara tatap muka k...
# 6             Adem,bersih,luas,cocok untuk mahasiswa
# 7                  Sejuk, tempat tepat untuk belajar
# 8  Saya sih cm di luar kampusnya aja.. G msk sih....
# 9  Karena letaknya yang sama dengan poltekpos, te...
#
#                                            temp_text
# 0  kampus kereendosennya sangat support lokasi te...
# 1  kampus yang nyaman suasana cukup heteorgen kar...
# 2  ada salah satu dosen yang mempersulit mahasisw...
# 3  sekolah tinggi pertama di indonesia yang berko...
# 4    kampus nya luas bersih dan bagus udaranya sejuk
# 5  sepi kuliah belum berjalan secara tatap muka k...
# 6                adembersihluascocok untuk mahasiswa
# 7                   sejuk tempat tepat untuk belajar
# 8  saya sih cuma di luar kampusnya saja g msk sih...
# 9  karena letaknya yang sama dengan poltekpos ten...

# %% [markdown]
# ## Removal of Stopwords

# %%
from nltk.corpus import stopwords
", ".join(stopwords.words('indonesian'))
# Out:
# 'ada, adalah, adanya, adapun, agak, agaknya, agar, akan, akankah, akhir, akhiri, akhirnya, aku, akulah, amat, amatlah, anda, andalah, antar, antara, antaranya, apa, apaan, apabila, apakah, apalagi, apatah, artinya, asal, asalkan, atas, atau, ataukah, ataupun, awal, awalnya, bagai, bagaikan, bagaimana, bagaimanakah, bagaimanapun, bagi, bagian, bahkan, bahwa, bahwasanya, baik, bakal, bakalan, balik, banyak, bapak, baru, bawah, beberapa, begini, beginian, beginikah, beginilah, begitu, begitukah, begitulah, begitupun, bekerja, belakang, belakangan, belum, belumlah, benar, benarkah, benarlah, berada, berakhir, berakhirlah, berakhirnya, berapa, berapakah, berapalah, berapapun, berarti, berawal, berbagai, berdatangan, beri, berikan, berikut, berikutnya, berjumlah, berkali-kali, berkata, berkehendak, berkeinginan, berkenaan, berlainan, berlalu, berlangsung, berlebihan, bermacam, bermacam-macam, bermaksud, bermula, bersama, bersama-sama, bersiap, bersiap-siap, bertanya, bertanya-tanya, berturut, berturut-turut, bertutur, berujar, berupa, besar, betul, betulkah, biasa, biasanya, bila, bilakah, bisa, bisakah, boleh, bolehkah, bolehlah, buat, bukan, bukankah, bukanlah, bukannya, bulan, bung, cara, caranya, cukup, cukupkah, cukuplah, cuma, dahulu, dalam, dan, dapat, dari, daripada, datang, dekat, demi, demikian, demikianlah, dengan, depan, di, dia, diakhiri, diakhirinya, dialah, diantara, diantaranya, diberi, diberikan, diberikannya, dibuat, dibuatnya, didapat, didatangkan, digunakan, diibaratkan, diibaratkannya, diingat, diingatkan, diinginkan, dijawab, dijelaskan, dijelaskannya, dikarenakan, dikatakan, dikatakannya, dikerjakan, diketahui, diketahuinya, dikira, dilakukan, dilalui, dilihat, dimaksud, dimaksudkan, dimaksudkannya, dimaksudnya, diminta, dimintai, dimisalkan, dimulai, dimulailah, dimulainya, dimungkinkan, dini, dipastikan, diperbuat, diperbuatnya, dipergunakan, diperkirakan, diperlihatkan, diperlukan, diperlukannya, dipersoalkan, dipertanyakan, dipunyai, diri, dirinya, disampaikan, disebut, disebutkan, disebutkannya, disini, disinilah, ditambahkan, ditandaskan, ditanya, ditanyai, ditanyakan, ditegaskan, ditujukan, ditunjuk, ditunjuki, ditunjukkan, ditunjukkannya, ditunjuknya, dituturkan, dituturkannya, diucapkan, diucapkannya, diungkapkan, dong, dua, dulu, empat, enggak, enggaknya, entah, entahlah, guna, gunakan, hal, hampir, hanya, hanyalah, hari, harus, haruslah, harusnya, hendak, hendaklah, hendaknya, hingga, ia, ialah, ibarat, ibaratkan, ibaratnya, ibu, ikut, ingat, ingat-ingat, ingin, inginkah, inginkan, ini, inikah, inilah, itu, itukah, itulah, jadi, jadilah, jadinya, jangan, jangankan, janganlah, jauh, jawab, jawaban, jawabnya, jelas, jelaskan, jelaslah, jelasnya, jika, jikalau, juga, jumlah, jumlahnya, justru, kala, kalau, kalaulah, kalaupun, kalian, kami, kamilah, kamu, kamulah, kan, kapan, kapankah, kapanpun, karena, karenanya, kasus, kata, katakan, katakanlah, katanya, ke, keadaan, kebetulan, kecil, kedua, keduanya, keinginan, kelamaan, kelihatan, kelihatannya, kelima, keluar, kembali, kemudian, kemungkinan, kemungkinannya, kenapa, kepada, kepadanya, kesampaian, keseluruhan, keseluruhannya, keterlaluan, ketika, khususnya, kini, kinilah, kira, kira-kira, kiranya, kita, kitalah, kok, kurang, lagi, lagian, lah, lain, lainnya, lalu, lama, lamanya, lanjut, lanjutnya, lebih, lewat, lima, luar, macam, maka, makanya, makin, malah, malahan, mampu, mampukah, mana, manakala, manalagi, masa, masalah, masalahnya, masih, masihkah, masing, masing-masing, mau, maupun, melainkan, melakukan, melalui, melihat, melihatnya, memang, memastikan, memberi, memberikan, membuat, memerlukan, memihak, meminta, memintakan, memisalkan, memperbuat, mempergunakan, memperkirakan, memperlihatkan, mempersiapkan, mempersoalkan, mempertanyakan, mempunyai, memulai, memungkinkan, menaiki, menambahkan, menandaskan, menanti, menanti-nanti, menantikan, menanya, menanyai, menanyakan, mendapat, mendapatkan, mendatang, mendatangi, mendatangkan, menegaskan, meng ...

# %%
from nltk.corpus import stopwords

STOPWORDS = set(stopwords.words('indonesian'))
def remove_stopwords(text):
    return " ".join([word for word in text.split() if word not in STOPWORDS])

# %%
df['temp_text'] = df['temp_text'].apply(lambda x: remove_stopwords(x))
df.head()
# Out:
#                     name  rating  \
# 0        Rian Syahariany     5.0
# 1  Ananda Hafizhah Putri     4.0
# 2       PRADYA PARAMITHA     1.0
# 3   Juli Amirah Nasution     5.0
# 4             Ayah Endah     5.0
#
#                                              snippet  \
# 0  Kampus kereen...dosennya sangat support lokasi...
# 1  Kampus yang nyaman. Suasana cukup heteorgen ka...
# 2  Ada salah satu dosen yg mempersulit mahasiswan...
# 3  Sekolah Tinggi pertama di Indonesia yang berko...
# 4  Kampus nya luas, bersih dan bagus. Udaranya se...
#
#                                            temp_text
# 0  kampus kereendosennya support lokasi tenang ny...
# 1  kampus nyaman suasana heteorgen mahasiswa bera...
# 2  salah dosen mempersulit mahasiswanya adik lulu...
# 3  sekolah indonesia berkonsentrasi dibidang logi...
# 4        kampus nya luas bersih bagus udaranya sejuk

# %% [markdown]
# ## !!!Removal of Frequent Words

# %%
# Menghapus semua kata "nya" yang berdiri sendiri dalam kolom temp_text
df['temp_text'] = df['temp_text'].apply(lambda text: ' '.join([word for word in text.split() if word != 'nya']))

df.head()
# Out:
#                     name  rating  \
# 0        Rian Syahariany     5.0
# 1  Ananda Hafizhah Putri     4.0
# 2       PRADYA PARAMITHA     1.0
# 3   Juli Amirah Nasution     5.0
# 4             Ayah Endah     5.0
#
#                                              snippet  \
# 0  Kampus kereen...dosennya sangat support lokasi...
# 1  Kampus yang nyaman. Suasana cukup heteorgen ka...
# 2  Ada salah satu dosen yg mempersulit mahasiswan...
# 3  Sekolah Tinggi pertama di Indonesia yang berko...
# 4  Kampus nya luas, bersih dan bagus. Udaranya se...
#
#                                            temp_text
# 0  kampus kereendosennya support lokasi tenang ny...
# 1  kampus nyaman suasana heteorgen mahasiswa bera...
# 2  salah dosen mempersulit mahasiswanya adik lulu...
# 3  sekolah indonesia berkonsentrasi dibidang logi...
# 4            kampus luas bersih bagus udaranya sejuk

# %%
from collections import Counter
word_count = Counter()
for text in df['temp_text']:
    for word in text.split():
        word_count[word] += 1
        
word_count.most_common(10)
# Out:
# [('kampus', 11),
#  ('bagus', 7),
#  ('kuliah', 5),
#  ('logistik', 5),
#  ('kampusnya', 5),
#  ('sejuk', 5),
#  ('nyaman', 4),
#  ('luas', 4),
#  ('stimlog', 4),
#  ('dosen', 4)]

# %%
df.head()
# Out:
#                     name  rating  \
# 0        Rian Syahariany     5.0
# 1  Ananda Hafizhah Putri     4.0
# 2       PRADYA PARAMITHA     1.0
# 3   Juli Amirah Nasution     5.0
# 4             Ayah Endah     5.0
#
#                                              snippet  \
# 0  Kampus kereen...dosennya sangat support lokasi...
# 1  Kampus yang nyaman. Suasana cukup heteorgen ka...
# 2  Ada salah satu dosen yg mempersulit mahasiswan...
# 3  Sekolah Tinggi pertama di Indonesia yang berko...
# 4  Kampus nya luas, bersih dan bagus. Udaranya se...
#
#                                            temp_text
# 0  kampus kereendosennya support lokasi tenang ny...
# 1  kampus nyaman suasana heteorgen mahasiswa bera...
# 2  salah dosen mempersulit mahasiswanya adik lulu...
# 3  sekolah indonesia berkonsentrasi dibidang logi...
# 4            kampus luas bersih bagus udaranya sejuk

# %%
# FREQUENT_WORDS = set(word for (word, wc) in word_count.most_common(3))
# def remove_freq_words(text):
#     return " ".join([word for word in text.split() if word not in FREQUENT_WORDS])

# %%
# df['temp_text'] = df['temp_text'].apply(lambda x: remove_freq_words(x))
# df.head()

# %% [markdown]
# ## Removal of Rare Words

# %%
# This cell should be moved after CELL INDEX 22
RARE_WORDS = set(word for (word, wc) in word_count.most_common()[:-10:-1])
print(RARE_WORDS)
# Out:
# {'in', 'bad', 'first', 'nice', 'university', 'smart', 'slog', 'green', 'top'}

# %%
def remove_rare_words(text):
    return " ".join([word for word in text.split() if word not in RARE_WORDS])

# %%
df['temp_text'] = df['temp_text'].apply(lambda x: remove_rare_words(x))
df.head()
# Out:
#                     name  rating  \
# 0        Rian Syahariany     5.0
# 1  Ananda Hafizhah Putri     4.0
# 2       PRADYA PARAMITHA     1.0
# 3   Juli Amirah Nasution     5.0
# 4             Ayah Endah     5.0
#
#                                              snippet  \
# 0  Kampus kereen...dosennya sangat support lokasi...
# 1  Kampus yang nyaman. Suasana cukup heteorgen ka...
# 2  Ada salah satu dosen yg mempersulit mahasiswan...
# 3  Sekolah Tinggi pertama di Indonesia yang berko...
# 4  Kampus nya luas, bersih dan bagus. Udaranya se...
#
#                                            temp_text
# 0  kampus kereendosennya support lokasi tenang ny...
# 1  kampus nyaman suasana heteorgen mahasiswa bera...
# 2  salah dosen mempersulit mahasiswanya adik lulu...
# 3  sekolah indonesia berkonsentrasi dibidang logi...
# 4            kampus luas bersih bagus udaranya sejuk

# %% [markdown]
# ## Removal of Special characters

# %%
import re
def remove_spl_chars(text):
    text = re.sub('[^a-zA-Z0-9]', ' ', text)
    text = re.sub('\s+', ' ', text)
    return text
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\s'
# <>:4: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\hp\AppData\Local\Temp\ipykernel_27676\688201358.py:4: SyntaxWarning: invalid escape sequence '\s'
#   text = re.sub('\s+', ' ', text)

# %%
df['temp_text'] = df['temp_text'].apply(lambda x: remove_spl_chars(x))
df.head()
# Out:
#                     name  rating  \
# 0        Rian Syahariany     5.0
# 1  Ananda Hafizhah Putri     4.0
# 2       PRADYA PARAMITHA     1.0
# 3   Juli Amirah Nasution     5.0
# 4             Ayah Endah     5.0
#
#                                              snippet  \
# 0  Kampus kereen...dosennya sangat support lokasi...
# 1  Kampus yang nyaman. Suasana cukup heteorgen ka...
# 2  Ada salah satu dosen yg mempersulit mahasiswan...
# 3  Sekolah Tinggi pertama di Indonesia yang berko...
# 4  Kampus nya luas, bersih dan bagus. Udaranya se...
#
#                                            temp_text
# 0  kampus kereendosennya support lokasi tenang ny...
# 1  kampus nyaman suasana heteorgen mahasiswa bera...
# 2  salah dosen mempersulit mahasiswanya adik lulu...
# 3  sekolah indonesia berkonsentrasi dibidang logi...
# 4            kampus luas bersih bagus udaranya sejuk

# %% [markdown]
# ## Stemming

# %%
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory

# Membuat stemmer bahasa Indonesia
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# Fungsi stemming
def stem_words(text):
    return stemmer.stem(text)

# %%
# Menerapkan stemming pada kolom temp_text
df['stemmed_text'] = df['temp_text'].apply(lambda x: stem_words(x))
df.head()
# Out:
#                     name  rating  \
# 0        Rian Syahariany     5.0
# 1  Ananda Hafizhah Putri     4.0
# 2       PRADYA PARAMITHA     1.0
# 3   Juli Amirah Nasution     5.0
# 4             Ayah Endah     5.0
#
#                                              snippet  \
# 0  Kampus kereen...dosennya sangat support lokasi...
# 1  Kampus yang nyaman. Suasana cukup heteorgen ka...
# 2  Ada salah satu dosen yg mempersulit mahasiswan...
# 3  Sekolah Tinggi pertama di Indonesia yang berko...
# 4  Kampus nya luas, bersih dan bagus. Udaranya se...
#
#                                            temp_text  \
# 0  kampus kereendosennya support lokasi tenang ny...
# 1  kampus nyaman suasana heteorgen mahasiswa bera...
# 2  salah dosen mempersulit mahasiswanya adik lulu...
# 3  sekolah indonesia berkonsentrasi dibidang logi...
# 4            kampus luas bersih bagus udaranya sejuk
#
#                                         stemmed_text
# 0  kampus kereendosennya support lokasi tenang ny...
# 1  kampus nyaman suasana heteorgen mahasiswa asal...
# 2  salah dosen sulit mahasiswa adik lulus kampus ...
# 3  sekolah indonesia konsentrasi bidang logistik ...
# 4               kampus luas bersih bagus udara sejuk

# %% [markdown]
# ## Lemmatization & POS Tagging

# %%
from nltk import pos_tag
from nltk.corpus import wordnet
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()
wordnet_map = {"N":wordnet.NOUN, "V": wordnet.VERB, "J": wordnet.ADJ, "R": wordnet.ADV}

def lemmatize_words(text):
    # find pos tags
    pos_text = pos_tag(text.split())
    return " ".join([lemmatizer.lemmatize(word, wordnet_map.get(pos[0], wordnet.NOUN)) for word, pos in pos_text])

# %%
from nltk.corpus import wordnet

wordnet.NOUN
# Out:
# 'n'

# %%
# import nltk
# nltk.download('averaged_perceptron_tagger')

# df['lemmatized_text'] = df['temp_text'].apply(lambda x: lemmatize_words(x))
# df.head()

# %%
df.sample(frac=1).head(10)
# Out:
#                                                  name  rating  \
# 20                                        Marten Beos     5.0
# 44                          Muhammad Sardafi Rais Nur     5.0
# 28                                Ilham Akhir Sahbana     5.0
# 34                                   Indra Mahyudi. S     5.0
# 30                                       Agus Suryana     5.0
# 32                                       Nabil Kusuma     5.0
# 21                                     Muhammad Akbar     5.0
# 16                                      Zahra Nadhifa     5.0
# 5   KDKW CENTER KOTA MOJOKERTO (Wa jek pak moh yusri)     3.0
# 31                             Muhammad Riyan Prayoga     5.0
#
#                                               snippet  \
# 20                   Anak sy kuliah di polban stimlog
# 44                           First S.Log in indonesia
# 28                                               Adem
# 34   Kampusnya asri, di atas bukit, sejuk dan nyaman.
# 30                                      Kampus Orange
# 32                                              Bagus
# 21                                       Sangat bagus
# 16                      Tempatnya bagus dan nyamana 🤩
# 5   Sepi kuliah belum berjalan secara tatap muka k...
# 31                                             Mantap
#
#                                        temp_text  \
# 20                    anak kuliah polban stimlog
# 44                                     indonesia
# 28                                          adem
# 34             kampusnya asri bukit sejuk nyaman
# 30                                 kampus orange
# 32                                         bagus
# 21                                         bagus
# 16                      tempatnya bagus nyamana
# 5   sepi kuliah berjalan tatap muka effek corona
# 31                                        mantap
#
#                                  stemmed_text
# 20                 anak kuliah polban stimlog
# 44                                  indonesia
# 28                                       adem
# 34             kampus asri bukit sejuk nyaman
# 30                              kampus orange
# 32                                      bagus
# 21                                      bagus
# 16                       tempat bagus nyamana
# 5   sepi kuliah jalan tatap muka effek corona
# 31                                     mantap

# %% [markdown]
# ## Tokenization

# %%
df.head()
# Out:
#                     name  rating  \
# 0        Rian Syahariany     5.0
# 1  Ananda Hafizhah Putri     4.0
# 2       PRADYA PARAMITHA     1.0
# 3   Juli Amirah Nasution     5.0
# 4             Ayah Endah     5.0
#
#                                              snippet  \
# 0  Kampus kereen...dosennya sangat support lokasi...
# 1  Kampus yang nyaman. Suasana cukup heteorgen ka...
# 2  Ada salah satu dosen yg mempersulit mahasiswan...
# 3  Sekolah Tinggi pertama di Indonesia yang berko...
# 4  Kampus nya luas, bersih dan bagus. Udaranya se...
#
#                                            temp_text  \
# 0  kampus kereendosennya support lokasi tenang ny...
# 1  kampus nyaman suasana heteorgen mahasiswa bera...
# 2  salah dosen mempersulit mahasiswanya adik lulu...
# 3  sekolah indonesia berkonsentrasi dibidang logi...
# 4            kampus luas bersih bagus udaranya sejuk
#
#                                         stemmed_text
# 0  kampus kereendosennya support lokasi tenang ny...
# 1  kampus nyaman suasana heteorgen mahasiswa asal...
# 2  salah dosen sulit mahasiswa adik lulus kampus ...
# 3  sekolah indonesia konsentrasi bidang logistik ...
# 4               kampus luas bersih bagus udara sejuk

# %%
df.isnull().sum()
# Out:
# name            0
# rating          0
# snippet         0
# temp_text       0
# stemmed_text    0
# dtype: int64

# %%
from nltk.tokenize import word_tokenize

# Tokenisasi
df['tokenized_text'] = df['stemmed_text'].apply(lambda x: word_tokenize(x))
df.head()
# Out:
#                     name  rating  \
# 0        Rian Syahariany     5.0
# 1  Ananda Hafizhah Putri     4.0
# 2       PRADYA PARAMITHA     1.0
# 3   Juli Amirah Nasution     5.0
# 4             Ayah Endah     5.0
#
#                                              snippet  \
# 0  Kampus kereen...dosennya sangat support lokasi...
# 1  Kampus yang nyaman. Suasana cukup heteorgen ka...
# 2  Ada salah satu dosen yg mempersulit mahasiswan...
# 3  Sekolah Tinggi pertama di Indonesia yang berko...
# 4  Kampus nya luas, bersih dan bagus. Udaranya se...
#
#                                            temp_text  \
# 0  kampus kereendosennya support lokasi tenang ny...
# 1  kampus nyaman suasana heteorgen mahasiswa bera...
# 2  salah dosen mempersulit mahasiswanya adik lulu...
# 3  sekolah indonesia berkonsentrasi dibidang logi...
# 4            kampus luas bersih bagus udaranya sejuk
#
#                                         stemmed_text  \
# 0  kampus kereendosennya support lokasi tenang ny...
# 1  kampus nyaman suasana heteorgen mahasiswa asal...
# 2  salah dosen sulit mahasiswa adik lulus kampus ...
# 3  sekolah indonesia konsentrasi bidang logistik ...
# 4               kampus luas bersih bagus udara sejuk
#
#                                       tokenized_text
# 0  [kampus, kereendosennya, support, lokasi, tena...
# 1  [kampus, nyaman, suasana, heteorgen, mahasiswa...
# 2  [salah, dosen, sulit, mahasiswa, adik, lulus, ...
# 3  [sekolah, indonesia, konsentrasi, bidang, logi...
# 4        [kampus, luas, bersih, bagus, udara, sejuk]

# %%
# Cleaned text
df['cleaned_text'] = df['tokenized_text']
df.head()
# Out:
#                     name  rating  \
# 0        Rian Syahariany     5.0
# 1  Ananda Hafizhah Putri     4.0
# 2       PRADYA PARAMITHA     1.0
# 3   Juli Amirah Nasution     5.0
# 4             Ayah Endah     5.0
#
#                                              snippet  \
# 0  Kampus kereen...dosennya sangat support lokasi...
# 1  Kampus yang nyaman. Suasana cukup heteorgen ka...
# 2  Ada salah satu dosen yg mempersulit mahasiswan...
# 3  Sekolah Tinggi pertama di Indonesia yang berko...
# 4  Kampus nya luas, bersih dan bagus. Udaranya se...
#
#                                            temp_text  \
# 0  kampus kereendosennya support lokasi tenang ny...
# 1  kampus nyaman suasana heteorgen mahasiswa bera...
# 2  salah dosen mempersulit mahasiswanya adik lulu...
# 3  sekolah indonesia berkonsentrasi dibidang logi...
# 4            kampus luas bersih bagus udaranya sejuk
#
#                                         stemmed_text  \
# 0  kampus kereendosennya support lokasi tenang ny...
# 1  kampus nyaman suasana heteorgen mahasiswa asal...
# 2  salah dosen sulit mahasiswa adik lulus kampus ...
# 3  sekolah indonesia konsentrasi bidang logistik ...
# 4               kampus luas bersih bagus udara sejuk
#
#                                       tokenized_text  \
# 0  [kampus, kereendosennya, support, lokasi, tena...
# 1  [kampus, nyaman, suasana, heteorgen, mahasiswa...
# 2  [salah, dosen, sulit, mahasiswa, adik, lulus, ...
# 3  [sekolah, indonesia, konsentrasi, bidang, logi...
# 4        [kampus, luas, bersih, bagus, udara, sejuk]
#
#                                         cleaned_text
# 0  [kampus, kereendosennya, support, lokasi, tena...
# 1  [kampus, nyaman, suasana, heteorgen, mahasiswa...
# 2  [salah, dosen, sulit, mahasiswa, adik, lulus, ...
# 3  [sekolah, indonesia, konsentrasi, bidang, logi...
# 4        [kampus, luas, bersih, bagus, udara, sejuk]

# %%
df.isnull().sum()
# Out:
# name              0
# rating            0
# snippet           0
# temp_text         0
# stemmed_text      0
# tokenized_text    0
# cleaned_text      0
# dtype: int64

# %%
import os

try:
	# Save the dataframe to a CSV file
	df.to_csv(output_path, index=False)
	print(f"DataFrame successfully saved to {output_path}")
except Exception as e:
	print(f"An error occurred: {e}")
# Out:
# DataFrame successfully saved to ../../dataset/cleaned-data/STIMLOG_Reviews_cleaned.csv
